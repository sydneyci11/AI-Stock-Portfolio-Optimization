# %% [markdown]
# # 篩選十年來始終存在的股票

# %%
# To identify stock codes (股票代碼) that appear consistently across a decade of stock information files.
import pandas as pd
import os

# Set the current working directory to where the stock information files are stored
file_path = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE"
os.chdir(file_path)

# Generate a list of file names 
file_names = [f"{year}{month:02d}.csv" for year in range(2010, 2020) for month in range(1, 13)]
# print(file_names)

# Initialize an empty DataFrame to hold all stock data
all_stocks = pd.DataFrame()


# Loop through each file name and concatenate its data to the all_stocks DataFrame
for file_name in file_names:
    #print(file_name)
    df = pd.read_csv(file_name)
    # Concatenate the current file's data
    all_stocks = pd.concat([all_stocks, df], ignore_index = True)
    #print(all_stocks)

# Check if the all_stocks DataFrame is not empty
if not all_stocks.empty:
    # Identify stocks that appear in all files by counting occurrences 
    # and checking if equal to the number of files
    common_stocks = all_stocks['股票代碼'].value_counts() == len(file_names) # '股票代碼' means 'stock code'
    # Filter to keep only stocks present in all files
    common_stocks = common_stocks[common_stocks].index.tolist()
    print("Stock codes present in all files: ", common_stocks)
    print("Total number of common stocks: ", len(common_stocks))
    
else:
    print("No common stock codes found")
# Out:
# Stock codes present in all files:  ['2489', '3406', '2448', '2466', '2486', '3059', '3050', '3031', '3049', '3008', '3019', '2426', '3038', '3024', '2499', '2406', '2409', '6206', '3060', '3231', '3494', '3515', '6117', '6128', '6166', '6235', '3504', '6277', '9912', '2323', '2340', '2349', '2374', '2393', '3481', '3557', '3535', '3062', '2450', '2455', '2485', '2498', '3025', '3027', '3045', '3047', '3311', '2439', '3380', '3419', '3596', '4904', '4906', '5388', '6136', '6142', '2444', '2419', '3054', '6176', '3576', '3593', '3622', '5305', '5484', '6120', '6164', '6168', '6209', '2412', '6226', '1102', '8072', '8105', '2314', '2332', '2345', '2402', '3057', '3002', '3022', '3017', '2451', '2454', '2458', '2481', '3006', '3014', '3016', '3034', '3035', '3041', '3056', '3094', '3189', '3443', '3532', '3545', '3588', '2449', '2441', '2436', '2329', '9918', '9926', '9931', '9937', '1437', '2302', '2303', '2330', '2425', '2338', '2344', '2351', '2363', '2369', '2379', '2401', '5471', '6202', '6239', '2399', '2377', '2380', '2382', '2385', '2387', '2395', '2397', '2417', '2365', '2424', '2442', '2465', '2474', '6216', '3005', '3013', '2376', '2362', '6243', '1604', '6257', '6271', '8016', '8081', '8110', '8131', '8261', '2301', '2358', '2305', '2324', '2331', '2352', '2353', '2356', '2357', '6152', '8101', '6283', '2461', '2354', '2360', '2371', '2373', '2390', '2404', '2423', '2433', '2464', '6285', '2477', '2482', '2488', '2495', '2497', '3018', '3030', '3052', '2317', '2312', '6112', '5203', '3048', '3055', '3209', '5434', '6189', '6281', '8070', '8112', '2427', '2453', '2468', '2471', '2480', '3021', '3029', '3130', '3356', '3305', '3450', '3518', '9914', '9919', '9921', '9924', '9925', '9927', '9930', '9933', '9934', '9935', '9938', '9939', '9940', '9942', '9943', '9944', '9945', '9955', '9917', '9911', '3617', '9910', '6139', '6192', '6196', '6197', '6201', '6215', '8021', '8201', '2062', '2514', '2904', '6184', '8033', '9902', '9904', '9905', '9907', '3040', '3036', '3033', '2431', '2456', '2457', '2460', '2462', '2467', '2472', '2476', '2478', '2483', '2484', '2492', '2493', '3003', '3011', '3015', '3023', '3026', '2440', '2428', '3037', '2421', '8926', '1582', '2059', '2308', '2313', '2316', '2327', '2328', '2355', '2367', '2368', '2375', '2383', '2392', '2413', '2415', '2420', '3032', '3042', '3028', '6205', '6224', '6251', '6269', '6282', '8039', '8046', '8103', '8163', '8213', '8249', '1435', '2347', '2359', '2414', '2430', '2459', '3010', '6213', '6191', '3044', '6155', '3058', '3090', '3229', '3296', '3308', '3376', '3501', '3533', '3605', '3607', '3653', '5469', '6108', '6115', '6133', '6141', '6153', '9908', '2405', '6505', '1905', '1307', '1907', '1305', '1909', '1532', '2002A', '2006', '2007', '1304', '2009', '2010', '2012', '2013', '1303', '2015', '2017', '2020', '1906', '1904', '2023', '1903', '1603', '1605', '1608', '1609', '1611', '1612', '1308', '1614', '1615', '1616', '1617', '1618', '1802', '1806', '1809', '1810', '1902', '2022', '2024', '6605', '2109', '2204', '2206', '2207', '2227', '1436', '1442', '1808', '2501', '2504', '1235', '2505', '1234', '1233', '2509', '2511', '2515', '2516', '2201', '2108', '1301', '2107', '2027', '1702', '1236', '2029', '2030', '2031', '2032', '2033', '2034', '2038', '9958', '2101', '2102', '2103', '2104', '2105', '2106', '8374', '4532', '2520', '1447', '1451', '1452', '1453', '1454', '1455', '1457', '1459', '1460', '1463', '1464', '1465', '1466', '1467', '1321', '1468', '1319', '1316', '1323', '1446', '1472', '1445', '1402', '1409', '1410', '1413', '1414', '1416', '1417', '1325', '1419', '1423', '1434', '1439', '1440', '1441', '1443', '1444', '1324', '1470', '1473', '4526', '1524', '1526', '1527', '1528', '1309', '1530', '1531', '1533', '1535', '1536', '1537', '2616', '1539', '1540', '1541', '1560', '1583', '2049', '1525', '1310', '1474', '1522', '1315', '1476', '1477', '4414', '1503', '1504', '1506', '1314', '1507', '1313', '1513', '1514', '1515', '1312A', '1517', '1519', '1 ...
# Total number of common stocks:  632

# %% [markdown]
# # 以十年平均成交量篩選股票 = 流動性

# %%
# To calculate the average trading volume over a decade for a set of common stocks, identifying their liquidity.
def calculate_average_trading_volume(df):
    # Create a copy of the DataFrame to avoid modifying the original data
    df = df.copy()
    
    # Convert trading volume to numeric, coercing errors to NaN
    df['本月成交量(千股)'] = pd.to_numeric(df['本月成交量(千股)'], errors='coerce')
    # Calculate the mean of the monthly trading volumes
    average_volume = df['本月成交量(千股)'].mean()
    
    return average_volume
# Change the current working directory to where the stock information files are stored
file_path = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE"
os.chdir(file_path)

# Generate a list of filenames
file_names = [f"{year}{month:02d}.csv" for year in range(2010, 2020) for month in range(1, 13)]

# Initialize a list to store the average volumes for each month
monthly_average_volumes = []

for file_name in file_names:
    df = pd.read_csv(file_name)
    
    # Filter the DataFrame to include only rows with stock codes present in the common_stocks list
    df_filtered = df[df['股票代碼'].isin(common_stocks)]
    
    # If the filtered DataFrame is not empty, calculate the monthly average volume
    if not df_filtered.empty:
        monthly_avg_vol = calculate_average_trading_volume(df_filtered)
        
        monthly_average_volumes.append(monthly_avg_vol)

# Calculate the overall average trading volume across all months
average_trading_volume = sum(monthly_average_volumes)/len(monthly_average_volumes)

print(f"The average of all monthly average trading volumes is: {average_trading_volume}")
# Out:
# The average of all monthly average trading volumes is: 57342.92360467928

# %% [markdown]
# # 計算預期回報 Expected Return Value

# %%
# To calculate the expected returns for each stock based on their monthly price changes, 
# and saves the updated DataFrame with an added column for expected returns.

# Function to calculate the expected return of stocks
# return type: float (in decimal form)
def calculate_expected_return(df):
    df = df.copy()
    
    # Initialize the 'expected return' column
    df['預期回報'] = None
    
    # Inner function to calculate expected return for each row
    def calculate_row_expected_return(row):
        try:
            # Convert current and previous month prices to float, handle '-' as None
            current_month_last_price = float(row['本月底市價(元)']) if row['本月底市價(元)'] != '-' else None
            previous_month_last_price = float(row['上月底市價(元)']) if row['上月底市價(元)'] != '-' else None

            # Calculate return if both prices are available
            if current_month_last_price is not None and previous_month_last_price is not None:
                return (current_month_last_price - previous_month_last_price) / previous_month_last_price
        except ValueError:
            pass
        # Return None if unable to calculate
        return None

    # Apply the inner function to each row to calculate expected returns
    df['預期回報'] = df.apply(calculate_row_expected_return, axis=1)
    
    return df

for file_name in file_names:
    df = pd.read_csv(file_name)
    
    # Filter DataFrame for stocks present in the common stocks list
    df_filtered = df[df['股票代碼'].isin(common_stocks)]
    
    if not df_filtered.empty:
        # Calculate the expected return for the filtered DataFrame
        df_with_return = calculate_expected_return(df_filtered)      
        print(f"Processed {file_name}")
        
        # Define the name for the result file
        result_file_name = file_name.replace('.csv', '_expected_return.csv')
        
        # Save the updated DataFrame with expected returns to a new file
        df_with_return.to_csv(result_file_name, index=False)
        print(f"Saved result to {result_file_name}")
# Out:
# Processed 201001.csv
# Saved result to 201001_expected_return.csv
# Processed 201002.csv
# Saved result to 201002_expected_return.csv
# Processed 201003.csv
# Saved result to 201003_expected_return.csv
# Processed 201004.csv
# Saved result to 201004_expected_return.csv
# Processed 201005.csv
# Saved result to 201005_expected_return.csv
# Processed 201006.csv
# Saved result to 201006_expected_return.csv
# Processed 201007.csv
# Saved result to 201007_expected_return.csv
# Processed 201008.csv
# Saved result to 201008_expected_return.csv
# Processed 201009.csv
# Saved result to 201009_expected_return.csv
# Processed 201010.csv
# Saved result to 201010_expected_return.csv
# Processed 201011.csv
# Saved result to 201011_expected_return.csv
# Processed 201012.csv
# Saved result to 201012_expected_return.csv
# Processed 201101.csv
# Saved result to 201101_expected_return.csv
# Processed 201102.csv
# Saved result to 201102_expected_return.csv
# Processed 201103.csv
# Saved result to 201103_expected_return.csv
# Processed 201104.csv
# Saved result to 201104_expected_return.csv
# Processed 201105.csv
# Saved result to 201105_expected_return.csv
# Processed 201106.csv
# Saved result to 201106_expected_return.csv
# Processed 201107.csv
# Saved result to 201107_expected_return.csv
# Processed 201108.csv
# Saved result to 201108_expected_return.csv
# Processed 201109.csv
# Saved result to 201109_expected_return.csv
# Processed 201110.csv
# Saved result to 201110_expected_return.csv
# Processed 201111.csv
# Saved result to 201111_expected_return.csv
# Processed 201112.csv
# Saved result to 201112_expected_return.csv
# Processed 201201.csv
# Saved result to 201201_expected_return.csv
# Processed 201202.csv
# Saved result to 201202_expected_return.csv
# Processed 201203.csv
# Saved result to 201203_expected_return.csv
# Processed 201204.csv
# Saved result to 201204_expected_return.csv
# Processed 201205.csv
# Saved result to 201205_expected_return.csv
# Processed 201206.csv
# Saved result to 201206_expected_return.csv
# Processed 201207.csv
# Saved result to 201207_expected_return.csv
# Processed 201208.csv
# Saved result to 201208_expected_return.csv
# Processed 201209.csv
# Saved result to 201209_expected_return.csv
# Processed 201210.csv
# Saved result to 201210_expected_return.csv
# Processed 201211.csv
# Saved result to 201211_expected_return.csv
# Processed 201212.csv
# Saved result to 201212_expected_return.csv
# Processed 201301.csv
# Saved result to 201301_expected_return.csv
# Processed 201302.csv
# Saved result to 201302_expected_return.csv
# Processed 201303.csv
# Saved result to 201303_expected_return.csv
# Processed 201304.csv
# Saved result to 201304_expected_return.csv
# Processed 201305.csv
# Saved result to 201305_expected_return.csv
# Processed 201306.csv
# Saved result to 201306_expected_return.csv
# Processed 201307.csv
# Saved result to 201307_expected_return.csv
# Processed 201308.csv
# Saved result to 201308_expected_return.csv
# Processed 201309.csv
# Saved result to 201309_expected_return.csv
# Processed 201310.csv
# Saved result to 201310_expected_return.csv
# Processed 201311.csv
# Saved result to 201311_expected_return.csv
# Processed 201312.csv
# Saved result to 201312_expected_return.csv
# Processed 201401.csv
# Saved result to 201401_expected_return.csv
# Processed 201402.csv
# Saved result to 201402_expected_return.csv
# Processed 201403.csv
# Saved result to 201403_expected_return.csv
# Processed 201404.csv
# Saved result to 201404_expected_return.csv
# Processed 201405.csv
# Saved result to 201405_expected_return.csv
# Processed 201406.csv
# Saved result to 201406_expected_return.csv
# Processed 201407.csv
# Saved result to 201407_expected_return.csv
# Processed 201408.csv
# Saved result to 201408_expected_return.csv
# Processed 201409.csv
# Saved result to 201409_expected_return.csv
# Processed 201410.csv
# Saved result to 201410_expected_return.csv
# Processed 201411.csv
# Saved result to 201411_expected_return.csv
# Processed 201412.csv
# Saved result to 201412_expected_return.csv
# Processed 201501.csv
# Saved result to 201501_expected_return.csv
# Processed 201502.csv
# Saved result to 201502_expected_return.csv
# Processed 201503.csv
# Saved result to 201503_expected_return.csv
# Processed 201504.csv
# Saved result to 201504_expected_return.csv
# Processed 201505.csv
# Saved result to 201505_expected_return.csv
# Processed 201506.csv
# Saved result to 201506_expected_return.csv
# Processed 201507.csv
# Saved result to 201507_expected_return.csv
# Processed 201508.csv
# Saved result to 201508_expected_return.csv
# Processed 201509.csv
# Saved result to 201509_expected_return.csv
# Processed 201510.csv
# Saved result to 201510_expected_return.csv
# Processed 201511.csv
# Saved result to 201511_expected_return.csv
# Processed 201512.csv
# Saved result to 201512_expected_return.csv
# Processed 201601.csv
# Saved result to 201601_expected_return.csv
# Processed 201602.csv
# Saved result to 201602_expected_return.csv
# Processed 201603.csv
# Saved result to 201603_expected_return.csv
# Processed 201604.csv
# Saved result to 201604_expected_return.csv
# Processed 201605.csv
# Saved result to 201605_expected_return.csv
# Processed 201606.csv
# Saved result to 201606_expected_return.csv
# Processed 201607.csv
# Saved result to 201607_expected_return.csv
# Processed 201608.csv
# Saved result to 201608_expected_return.csv
# Processed 201609.csv
# Saved result to 201609_expected_return.csv
# Processed 201610.csv
# Saved result to 201610_expected_return.csv
# Processed 201611.csv
# Saved result to 201611_expected_return.csv
# Processed 201612.csv
# Saved result to 201612_expected_return.csv
# Processed 201701.csv
# Saved result to 201701_expected_return.csv
# Processed 201702.csv
# Saved result to 201702_expected_return.csv
# Processed 201703.csv
# Saved result to 201703_expected_return.csv
# Processed 201704.csv
# Saved result to 201704_expected_return.csv
# Processed 201705.csv
# Saved result to 201705_expected_return.csv
# Processed 201706.csv
# Saved result to 201706_expected_return.csv
# Processed 201707.csv
# Saved result to 201707_expected_return.csv
# Processed 201708.csv
# Saved result to 201708_expected_return.csv
# Processed 201709.csv
# Saved result to 201709_expected_return.csv
# Processed 201710.csv
# Saved result to 201710_expected_return.csv
# Processed 201711.csv
# Saved result to 201711_expected_return.csv
# Processed 201712.csv
# Saved result to 201712_expected_return.csv
# Processed 201801.csv
# Saved result to 201801_expected_return.csv
# Processed 201802.csv
# Saved result to 201802_expected_return.csv
# Processed 201803.csv
# Saved result to 201803_expected_return.csv
# Processed 201804.csv
# Saved result to 201804_expected_return.csv
# Processed 201805.csv
# Saved result to 201805_expected_return.csv
# Processed 201806.csv
# Saved result to 201806_expected_return.csv
# Processed 201807.csv
# Saved result to 201807_expected_return.csv
# Processed 201808.csv
# Saved result to 201808_expected_return.csv
# Processed 201809.csv
# Saved result to 201809_expected_return.csv
# Processed 201810.csv
# Saved result to 201810_expected_return.csv
# Processed 201811.csv
# Saved result to 201811_expected_return.csv
# Processed 201812.csv
# Saved result to 201812_expected_return.csv
# Processed 201901.csv
# Saved result to 201901_expected_return.csv
# Processed 201902.csv
# Saved result to 201902_expected_return.csv
# Processed 201903.csv
# Saved result to 201903_expected_return.csv
# Processed 201904.csv
# Saved result to 201904_expected_return.csv
# Processed 201905.csv
# Saved result to 201905_expected_return.csv
# Processed 201906.csv
# Saved result to 201906_expected_return.csv
# Processed 201907.csv
# Saved result to 201907_expected_return.csv
# Processed 201908.csv
# Saved result to 201908_expected_return.csv
# Processed 201909.csv
# Saved result to 201909_expected_return.csv
# Processed 201910.csv
# Saved result to 201910_expected_return.csv
# Processed 201911.csv
# Saved result to 201911_expected_return.csv
# Processed 201912.csv
# Saved result to 201912_expected_return.csv

# %% [markdown]
# #

# %% [markdown]
# # 將每一支股票120個月的數據分別儲存

# %%
# To store data for each stock separately over 120 months
import pandas as pd
import os

# Set the directory where the stock information files are stored
file_path = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE"
os.chdir(file_path)

# Generate a list of filenames
file_names = [f"{year}{month:02d}_expected_return.csv" for year in range(2010, 2020) for month in range(1, 13)]
#print(file_names)

# Specify the columns to keep from each file
columns_to_keep = ['股票代碼', '股票名稱','本月成交量(千股)', '預期回報']

# Initialize a dictionary to store data for each stock separately
data_per_stock = {}

for file_name in file_names:
    df = pd.read_csv(file_name, usecols=columns_to_keep)
    print(f"Now processing {file_name}.")
    
    # Extract the date from the filename
    date = file_name[:6]
    # print(date)
    
    # Add the extracted date as a new column to the DataFrame
    df['日期'] = date
    
    for index, row in df.iterrows():
        stock_code = row['股票代碼']
        
        # Initialize a new DataFrame for the stock code if it doesn't exist in the dictionary
        if stock_code not in data_per_stock:
            data_per_stock[stock_code] = pd.DataFrame(columns=df.columns)
        
        # Concatenate the current row to the corresponding stock's DataFrame
        data_per_stock[stock_code] = pd.concat([data_per_stock[stock_code], pd.DataFrame([row])], ignore_index=True)
# Out:
# Now processing 201001_expected_return.csv.
# 201001
# Now processing 201002_expected_return.csv.
# 201002
# Now processing 201003_expected_return.csv.
# 201003
# Now processing 201004_expected_return.csv.
# 201004
# Now processing 201005_expected_return.csv.
# 201005
# Now processing 201006_expected_return.csv.
# 201006
# Now processing 201007_expected_return.csv.
# 201007
# Now processing 201008_expected_return.csv.
# 201008
# Now processing 201009_expected_return.csv.
# 201009
# Now processing 201010_expected_return.csv.
# 201010
# Now processing 201011_expected_return.csv.
# 201011
# Now processing 201012_expected_return.csv.
# 201012
# Now processing 201101_expected_return.csv.
# 201101
# Now processing 201102_expected_return.csv.
# 201102
# Now processing 201103_expected_return.csv.
# 201103
# Now processing 201104_expected_return.csv.
# 201104
# Now processing 201105_expected_return.csv.
# 201105
# Now processing 201106_expected_return.csv.
# 201106
# Now processing 201107_expected_return.csv.
# 201107
# Now processing 201108_expected_return.csv.
# 201108
# Now processing 201109_expected_return.csv.
# 201109
# Now processing 201110_expected_return.csv.
# 201110
# Now processing 201111_expected_return.csv.
# 201111
# Now processing 201112_expected_return.csv.
# 201112
# Now processing 201201_expected_return.csv.
# 201201
# Now processing 201202_expected_return.csv.
# 201202
# Now processing 201203_expected_return.csv.
# 201203
# Now processing 201204_expected_return.csv.
# 201204
# Now processing 201205_expected_return.csv.
# 201205
# Now processing 201206_expected_return.csv.
# 201206
# Now processing 201207_expected_return.csv.
# 201207
# Now processing 201208_expected_return.csv.
# 201208
# Now processing 201209_expected_return.csv.
# 201209
# Now processing 201210_expected_return.csv.
# 201210
# Now processing 201211_expected_return.csv.
# 201211
# Now processing 201212_expected_return.csv.
# 201212
# Now processing 201301_expected_return.csv.
# 201301
# Now processing 201302_expected_return.csv.
# 201302
# Now processing 201303_expected_return.csv.
# 201303
# Now processing 201304_expected_return.csv.
# 201304
# Now processing 201305_expected_return.csv.
# 201305
# Now processing 201306_expected_return.csv.
# 201306
# Now processing 201307_expected_return.csv.
# 201307
# Now processing 201308_expected_return.csv.
# 201308
# Now processing 201309_expected_return.csv.
# 201309
# Now processing 201310_expected_return.csv.
# 201310
# Now processing 201311_expected_return.csv.
# 201311
# Now processing 201312_expected_return.csv.
# 201312
# Now processing 201401_expected_return.csv.
# 201401
# Now processing 201402_expected_return.csv.
# 201402
# Now processing 201403_expected_return.csv.
# 201403
# Now processing 201404_expected_return.csv.
# 201404
# Now processing 201405_expected_return.csv.
# 201405
# Now processing 201406_expected_return.csv.
# 201406
# Now processing 201407_expected_return.csv.
# 201407
# Now processing 201408_expected_return.csv.
# 201408
# Now processing 201409_expected_return.csv.
# 201409
# Now processing 201410_expected_return.csv.
# 201410
# Now processing 201411_expected_return.csv.
# 201411
# Now processing 201412_expected_return.csv.
# 201412
# Now processing 201501_expected_return.csv.
# 201501
# Now processing 201502_expected_return.csv.
# 201502
# Now processing 201503_expected_return.csv.
# 201503
# Now processing 201504_expected_return.csv.
# 201504
# Now processing 201505_expected_return.csv.
# 201505
# Now processing 201506_expected_return.csv.
# 201506
# Now processing 201507_expected_return.csv.
# 201507
# Now processing 201508_expected_return.csv.
# 201508
# Now processing 201509_expected_return.csv.
# 201509
# Now processing 201510_expected_return.csv.
# 201510
# Now processing 201511_expected_return.csv.
# 201511
# Now processing 201512_expected_return.csv.
# 201512
# Now processing 201601_expected_return.csv.
# 201601
# Now processing 201602_expected_return.csv.
# 201602
# Now processing 201603_expected_return.csv.
# 201603
# Now processing 201604_expected_return.csv.
# 201604
# Now processing 201605_expected_return.csv.
# 201605
# Now processing 201606_expected_return.csv.
# 201606
# Now processing 201607_expected_return.csv.
# 201607
# Now processing 201608_expected_return.csv.
# 201608
# Now processing 201609_expected_return.csv.
# 201609
# Now processing 201610_expected_return.csv.
# 201610
# Now processing 201611_expected_return.csv.
# 201611
# Now processing 201612_expected_return.csv.
# 201612
# Now processing 201701_expected_return.csv.
# 201701
# Now processing 201702_expected_return.csv.
# 201702
# Now processing 201703_expected_return.csv.
# 201703
# Now processing 201704_expected_return.csv.
# 201704
# Now processing 201705_expected_return.csv.
# 201705
# Now processing 201706_expected_return.csv.
# 201706
# Now processing 201707_expected_return.csv.
# 201707
# Now processing 201708_expected_return.csv.
# 201708
# Now processing 201709_expected_return.csv.
# 201709
# Now processing 201710_expected_return.csv.
# 201710
# Now processing 201711_expected_return.csv.
# 201711
# Now processing 201712_expected_return.csv.
# 201712
# Now processing 201801_expected_return.csv.
# 201801
# Now processing 201802_expected_return.csv.
# 201802
# Now processing 201803_expected_return.csv.
# 201803
# Now processing 201804_expected_return.csv.
# 201804
# Now processing 201805_expected_return.csv.
# 201805
# Now processing 201806_expected_return.csv.
# 201806
# Now processing 201807_expected_return.csv.
# 201807
# Now processing 201808_expected_return.csv.
# 201808
# Now processing 201809_expected_return.csv.
# 201809
# Now processing 201810_expected_return.csv.
# 201810
# Now processing 201811_expected_return.csv.
# 201811
# Now processing 201812_expected_return.csv.
# 201812
# Now processing 201901_expected_return.csv.
# 201901
# Now processing 201902_expected_return.csv.
# 201902
# Now processing 201903_expected_return.csv.
# 201903
# Now processing 201904_expected_return.csv.
# 201904
# Now processing 201905_expected_return.csv.
# 201905
# Now processing 201906_expected_return.csv.
# 201906
# Now processing 201907_expected_return.csv.
# 201907
# Now processing 201908_expected_return.csv.
# 201908
# Now processing 201909_expected_return.csv.
# 201909
# Now processing 201910_expected_return.csv.
# 201910
# Now processing 201911_expected_return.csv.
# 201911
# Now processing 201912_expected_return.csv.
# 201912

# %%
# To store data for each stock separately over 120 months
import pandas as pd
import os

# Set the directory where the stock information files are stored
file_path = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE"
os.chdir(file_path)

# Generate a list of filenames
file_names = [f"{year}{month:02d}_expected_return.csv" for year in range(2010, 2020) for month in range(1, 13)]
#print(file_names)

# Specify the columns to keep from each file
columns_to_keep = ['股票代碼', '股票名稱','本月成交量(千股)', '預期回報']

# Initialize a dictionary to store data for each stock separately
data_per_stock = {}

for file_name in file_names:
    df = pd.read_csv(file_name, usecols=columns_to_keep)
    print(f"Now processing {file_name}.")
    
    # Extract the date from the filename
    date = file_name[:6]
    # print(date)
    
    # Add the extracted date as a new column to the DataFrame
    df['日期'] = date
    
    for index, row in df.iterrows():
        stock_code = row['股票代碼']
        
        # Initialize a new DataFrame for the stock code if it doesn't exist in the dictionary
        if stock_code not in data_per_stock:
            data_per_stock[stock_code] = pd.DataFrame(columns=df.columns)
        
        # Concatenate the current row to the corresponding stock's DataFrame
        data_per_stock[stock_code] = pd.concat([data_per_stock[stock_code], pd.DataFrame([row])], ignore_index=True)

# The folder path that the stock info is going to be sorted 
target_folder = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE\per_stock_data"

stock_file_names = []

# Ensure the target folder exists; if not, create it
if not os.path.exists(target_folder):
    os.makedirs(target_folder)
    
else:
    # Change the working directory to the target folder
    os.chdir(target_folder)

# Iterate through the dictionary, saving a CSV file for each stock
for stock_code, df in data_per_stock.items():
    # Get the unique stock name from the DataFrame (assuming the same stock code has a consistent name)
    stock_name = df['股票名稱'].iloc[0]
    # Combine the stock code and stock name to form the filename
    output_filename = f"{stock_code}_{stock_name}.csv"
    # Replace any characters in the filename that may be invalid for file paths
    output_filename = output_filename.replace('/', '_').replace('\\', '_')
    print(f"Saving {output_filename}")
    df.to_csv(output_filename, index=False)
    print(f"{output_filename} saving success.")
    # Keep track of the names of the files saved
    stock_file_names.append(output_filename)

# print(stock_file_names)
# print(len(stock_file_names))
# Out:
# Now processing 201001_expected_return.csv.
# Now processing 201002_expected_return.csv.
# Now processing 201003_expected_return.csv.
# Now processing 201004_expected_return.csv.
# Now processing 201005_expected_return.csv.
# Now processing 201006_expected_return.csv.
# Now processing 201007_expected_return.csv.
# Now processing 201008_expected_return.csv.
# Now processing 201009_expected_return.csv.
# Now processing 201010_expected_return.csv.
# Now processing 201011_expected_return.csv.
# Now processing 201012_expected_return.csv.
# Now processing 201101_expected_return.csv.
# Now processing 201102_expected_return.csv.
# Now processing 201103_expected_return.csv.
# Now processing 201104_expected_return.csv.
# Now processing 201105_expected_return.csv.
# Now processing 201106_expected_return.csv.
# Now processing 201107_expected_return.csv.
# Now processing 201108_expected_return.csv.
# Now processing 201109_expected_return.csv.
# Now processing 201110_expected_return.csv.
# Now processing 201111_expected_return.csv.
# Now processing 201112_expected_return.csv.
# Now processing 201201_expected_return.csv.
# Now processing 201202_expected_return.csv.
# Now processing 201203_expected_return.csv.
# Now processing 201204_expected_return.csv.
# Now processing 201205_expected_return.csv.
# Now processing 201206_expected_return.csv.
# Now processing 201207_expected_return.csv.
# Now processing 201208_expected_return.csv.
# Now processing 201209_expected_return.csv.
# Now processing 201210_expected_return.csv.
# Now processing 201211_expected_return.csv.
# Now processing 201212_expected_return.csv.
# Now processing 201301_expected_return.csv.
# Now processing 201302_expected_return.csv.
# Now processing 201303_expected_return.csv.
# Now processing 201304_expected_return.csv.
# Now processing 201305_expected_return.csv.
# Now processing 201306_expected_return.csv.
# Now processing 201307_expected_return.csv.
# Now processing 201308_expected_return.csv.
# Now processing 201309_expected_return.csv.
# Now processing 201310_expected_return.csv.
# Now processing 201311_expected_return.csv.
# Now processing 201312_expected_return.csv.
# Now processing 201401_expected_return.csv.
# Now processing 201402_expected_return.csv.
# Now processing 201403_expected_return.csv.
# Now processing 201404_expected_return.csv.
# Now processing 201405_expected_return.csv.
# Now processing 201406_expected_return.csv.
# Now processing 201407_expected_return.csv.
# Now processing 201408_expected_return.csv.
# Now processing 201409_expected_return.csv.
# Now processing 201410_expected_return.csv.
# Now processing 201411_expected_return.csv.
# Now processing 201412_expected_return.csv.
# Now processing 201501_expected_return.csv.
# Now processing 201502_expected_return.csv.
# Now processing 201503_expected_return.csv.
# Now processing 201504_expected_return.csv.
# Now processing 201505_expected_return.csv.
# Now processing 201506_expected_return.csv.
# Now processing 201507_expected_return.csv.
# Now processing 201508_expected_return.csv.
# Now processing 201509_expected_return.csv.
# Now processing 201510_expected_return.csv.
# Now processing 201511_expected_return.csv.
# Now processing 201512_expected_return.csv.
# Now processing 201601_expected_return.csv.
# Now processing 201602_expected_return.csv.
# Now processing 201603_expected_return.csv.
# Now processing 201604_expected_return.csv.
# Now processing 201605_expected_return.csv.
# Now processing 201606_expected_return.csv.
# Now processing 201607_expected_return.csv.
# Now processing 201608_expected_return.csv.
# Now processing 201609_expected_return.csv.
# Now processing 201610_expected_return.csv.
# Now processing 201611_expected_return.csv.
# Now processing 201612_expected_return.csv.
# Now processing 201701_expected_return.csv.
# Now processing 201702_expected_return.csv.
# Now processing 201703_expected_return.csv.
# Now processing 201704_expected_return.csv.
# Now processing 201705_expected_return.csv.
# Now processing 201706_expected_return.csv.
# Now processing 201707_expected_return.csv.
# Now processing 201708_expected_return.csv.
# Now processing 201709_expected_return.csv.
# Now processing 201710_expected_return.csv.
# Now processing 201711_expected_return.csv.
# Now processing 201712_expected_return.csv.
# Now processing 201801_expected_return.csv.
# Now processing 201802_expected_return.csv.
# Now processing 201803_expected_return.csv.
# Now processing 201804_expected_return.csv.
# Now processing 201805_expected_return.csv.
# Now processing 201806_expected_return.csv.
# Now processing 201807_expected_return.csv.
# Now processing 201808_expected_return.csv.
# Now processing 201809_expected_return.csv.
# Now processing 201810_expected_return.csv.
# Now processing 201811_expected_return.csv.
# Now processing 201812_expected_return.csv.
# Now processing 201901_expected_return.csv.
# Now processing 201902_expected_return.csv.
# Now processing 201903_expected_return.csv.
# Now processing 201904_expected_return.csv.
# Now processing 201905_expected_return.csv.
# Now processing 201906_expected_return.csv.
# Now processing 201907_expected_return.csv.
# Now processing 201908_expected_return.csv.
# Now processing 201909_expected_return.csv.
# Now processing 201910_expected_return.csv.
# Now processing 201911_expected_return.csv.
# Now processing 201912_expected_return.csv.
# Saving 1102_亞洲水泥 ACC.csv
# 1102_亞洲水泥 ACC.csv saving success.
# Saving 1103_嘉新水泥 CHC.csv
# 1103_嘉新水泥 CHC.csv saving success.
# Saving 1104_環球水泥 UCC.csv
# 1104_環球水泥 UCC.csv saving success.
# Saving 1108_幸福水泥 Lucky Cement.csv
# 1108_幸福水泥 Lucky Cement.csv saving success.
# Saving 1109_信大水泥 HsingTa.csv
# 1109_信大水泥 HsingTa.csv saving success.
# Saving 1110_東南水泥 TUNA CEMENT.csv
# 1110_東南水泥 TUNA CEMENT.csv saving success.
# Saving 1201_味全食品 Wei-Chuan.csv
# 1201_味全食品 Wei-Chuan.csv saving success.
# Saving 1203_味王 Ve Wong.csv
# 1203_味王 Ve Wong.csv saving success.
# Saving 1210_大成長城 GREATWALL.csv
# 1210_大成長城 GREATWALL.csv saving success.
# Saving 1215_卜蜂企業 CPE.csv
# 1215_卜蜂企業 CPE.csv saving success.
# Saving 1216_統一企業 PEC.csv
# 1216_統一企業 PEC.csv saving success.
# Saving 1217_愛之味 AGV.csv
# 1217_愛之味 AGV.csv saving success.
# Saving 1218_泰山 TAISUN.csv
# 1218_泰山 TAISUN.csv saving success.
# Saving 1219_福壽 FWUSOW.csv
# 1219_福壽 FWUSOW.csv saving success.
# Saving 1220_台榮 TAIROUN.csv
# 1220_台榮 TAIROUN.csv saving success.
# Saving 1225_福懋油脂 FOPCO.csv
# 1225_福懋油脂 FOPCO.csv saving success.
# Saving 1227_佳格食品 S.F.C.csv
# 1227_佳格食品 S.F.C.csv saving success.
# Saving 1229_聯華實業 LHIC.csv
# 1229_聯華實業 LHIC.csv saving success.
# Saving 1231_聯華食品 Lian Hwa Foods.csv
# 1231_聯華食品 Lian Hwa Foods.csv saving success.
# Saving 1232_大統益 TTET.csv
# 1232_大統益 TTET.csv saving success.
# Saving 1233_天仁 Ten Ren.csv
# 1233_天仁 Ten Ren.csv saving success.
# Saving 1234_黑松 Hey-Song.csv
# 1234_黑松 Hey-Song.csv saving success.
# Saving 1235_興泰 Shin Tai.csv
# 1235_興泰 Shin Tai.csv saving success.
# Saving 1236_宏亞食品 Hunya Foods.csv
# 1236_宏亞食品 Hunya Foods.csv saving success.
# Saving 1702_南僑化工 NAMCHOW.csv
# 1702_南僑化工 NAMCHOW.csv saving success.
# Saving 1301_臺灣塑膠 FPC.csv
# 1301_臺灣塑膠 FPC.csv saving success.
# Saving 1303_南亞塑膠 NPC.csv
# 1303_南亞塑膠 NPC.csv saving success.
# Saving 1304_臺灣聚合 USI.csv
# 1304_臺灣聚合 USI.csv saving success.
# Saving 1305_華夏塑膠 CGPC.csv
# 1305_華夏塑膠 CGPC.csv saving success.
# Saving 1307_三芳化工 SAN FANG.csv
# 1307_三芳化工 SAN FANG.csv saving success.
# Saving 1308_亞聚 APC.csv
# 1308_亞聚 APC.csv saving success.
# Saving 1309_台達化 TTC.csv
# 1309_台達化 TTC.csv saving success.
# Saving 1310_臺灣苯乙烯 T.S.M.C..csv
# 1310_臺灣苯乙烯 T.S.M.C..csv saving success.
# Saving 1312A_國喬石化        (特 別) GPPC preferred.csv
# 1312A_國喬石化        (特 別) GPPC preferred.csv saving success.
# Saving 1313_聯成 UPC.csv
# 1313_聯成 UPC.csv saving success.
# Saving 1314_中石化 CPDC.csv
# 1314_中石化 CPDC.csv saving success.
# Saving 1315_達新工業 TAHHSIN.csv
# 1315_達新工業 TAHHSIN.csv saving success.
# Saving 1316_上曜 SUN YAD.csv
# 1316_上曜 SUN YAD.csv saving success.
# Saving 1319_東陽 TYG.csv
# 1319_東陽 TYG.csv saving success.
# Saving 1321_大洋 OPC.csv
# 1321_大洋 OPC.csv saving success.
# Saving 1323_永裕 YONYU.csv
# 1323_永裕 YONYU.csv saving success.
# Saving 1324_地球 Globe.csv
# 1324_地球 Globe.csv saving success.
# Saving 1325_恒大 UK.csv
# 1325_恒大 UK.csv saving success.
# Saving 1326_臺灣化纖 FCFC.csv
# 1326_臺灣化纖 FCFC.csv saving success.
# Saving 4306_炎洲 YEMCHIO.csv
# 4306_炎洲 YEMCHIO.csv saving success.
# Saving 1402_遠東新 FENC.csv
# 1402_遠東新 FENC.csv saving success.
# Saving 1409_新光合纖 SSFC.csv
# 1409_新光合纖 SSFC.csv saving success.
# Saving 1410_南洋染整 NYDF.csv
# 1410_南洋染整 NYDF.csv saving success.
# Saving 1413_宏洲化工 H.C..csv
# 1413_宏洲化工 H.C..csv saving success.
# Saving 1414_東和紡織 TUNG HO.csv
# 1414_東和紡織 TUNG HO.csv saving success.
# Saving 1416_廣豐實業 KFIC.csv
# 1416_廣豐實業 KFIC.csv saving success.
# Saving 1417_嘉裕 Carnival.csv
# 1417_嘉裕 Carnival.csv saving success.
# Saving 1419_新光紡織 SHINKO.SPIN..csv
# 1419_新光紡織 SHINKO.SPIN..csv saving success.
# Saving 1423_利華羊毛 Reward Wool.csv
# 1423_利華羊毛 Reward Wool.csv saving success.
# Saving 1434_福懋 Formosa Taffeta.csv
# 1434_福懋 Formosa Taffeta.csv saving success.
# Saving 1439_中和羊毛 Chuwa Wool.csv
# 1439_中和羊毛 Chuwa Wool.csv saving success.
# Saving 1440_台南紡織 Tainan Spinning.csv
# 1440_台南紡織 Tainan Spinning.csv saving success.
# Saving 1441_大東紡織 Tah Tong.csv
# 1441_大東紡織 Tah Tong.csv saving success.
# Saving 1443_立益紡織 LILYTEXTILE.csv
# 1443_立益紡織 LILYTEXTILE.csv saving success.
# Saving 1444_力麗 LEALEA.csv
# 1444_力麗 LEALEA.csv saving success.
# Saving 1445_大宇紡織 Universal.csv
# 1445_大宇紡織 Universal.csv saving success.
# Saving 1446_宏和紡織 Hong Ho.csv
# 1446_宏和紡織 Hong Ho.csv saving success.
# Saving 1447_力鵬 LP.csv
# 1447_力鵬 LP.csv saving success.
# Saving 1451_年興紡織 NIEN HSING.csv
# 1451_年興紡織 NIEN HSING.csv saving success.
# Saving 1452_宏益纖維 HONG YI.csv
# 1452_宏益纖維 HONG YI.csv saving success.
# Saving 1453_大將 TA JIANG.csv
# 1453_大將 TA JIANG.csv saving success.
# Saving 1454_臺灣富綢 TTF.csv
# 1454_臺灣富綢 TTF.csv saving success.
# Saving 1455_集盛 ZIG SHENG.csv
# 1455_集盛 ZIG SHENG.csv saving success.
# Saving 1457_宜進 YI JINN.csv
# 1457_宜進 YI JINN.csv saving success.
# Saving 1459_聯發紡織 Lan Fa Textile.csv
# 1459_聯發紡織 Lan Fa Textile.csv saving success.
# Saving 1460_宏遠 Everest Textile.csv
# 1460_宏遠 Everest Textile.csv saving success.
# Saving 1463_強盛染整 CS.csv
# 1463_強盛染整 CS.csv saving success.
# Saving 1464_得力 DE LICACY.csv
# 1464_得力 DE LICACY.csv saving success.
# Saving 1465_偉全 WISHER.csv
# 1465_偉全 WISHER.csv saving success.
# Saving 1466_聚隆纖維 Acelon.csv
# 1466_聚隆纖維 Acelon.csv saving success.
# Saving 1467_南緯 TEX-RAY.csv
# 1467_南緯 TEX-RAY.csv saving success.
# Saving 1468_昶和纖維 CHANG HO.csv
# 1468_昶和纖維 CHANG HO.csv saving success.
# Saving 1470_大統染 EVERTEX.csv
# 1470_大統染 EVERTEX.csv saving success.
# Saving 1472_三洋纖維 Tri Ocean.csv
# 1472_三洋纖維 Tri Ocean.csv saving success.
# Saving 1473_台南企業 Tainan.csv
# 1473_台南企業 Tainan.csv saving success.
# Saving 1474_弘裕 HONMYUE.csv
# 1474_弘裕 HONMYUE.csv saving success.
# Saving 1476_儒鴻企業 ECLAT.csv
# 1476_儒鴻企業 ECLAT.csv saving success.
# Saving 1477_聚陽 Makalot.csv
# 1477_聚陽 Makalot.csv saving success.
# Saving 4414_如興 ROO HSING.csv
# 4414_如興 ROO HSING.csv saving success.
# Saving 1503_士林電機 SEEC.csv
# 1503_士林電機 SEEC.csv saving success.
# Saving 1504_東元電機 TECO.csv
# 1504_東元電機 TECO.csv saving success.
# Saving 1506_正道 R.W..csv
# 1506_正道 R.W..csv saving success.
# Saving 1507_永大機電 YUNGTAY.csv
# 1507_永大機電 YUNGTAY.csv saving success.
# Saving 1513_中興電工 CHEM.csv
# 1513_中興電工 CHEM.csv saving success.
# Saving 1514_亞力電機 AEC.csv
# 1514_亞力電機 AEC.csv saving success.
# Saving 1515_力山工業 REXON.csv
# 1515_力山工業 REXON.csv saving success.
# Saving 1517_利奇機械 Lee Chi.csv
# 1517_利奇機械 Lee Chi.csv saving success.
# Saving 1519_華城電機 FE.csv
# 1519_華城電機 FE.csv saving success.
# Saving 1521_大億 DAIOKU.csv
# 1521_大億 DAIOKU.csv saving success.
# Saving 1522_堤維西 TYC.csv
# 1522_堤維西 TYC.csv saving success.
# Saving 1524_耿鼎 GORDON.csv
# 1524_耿鼎 GORDON.csv saving success.
# Saving 1525_江申 KSC.csv
# 1525_江申 KSC.csv saving success.
# Saving 1526_日馳 SUNRACE.csv
# 1526_日馳 SUNRACE.csv saving success.
# Saving 1527_鑽全 BASSO.csv
# 1527_鑽全 BASSO.csv saving success.
# Saving 1528_恩德科技 Anderson.csv
# 1528_恩德科技 Anderson.csv saving success.
# Saving 1530_亞崴電機 Awea.csv
# 1530_亞崴電機 Awea.csv saving success.
# Saving 1531_高林股 Kaulin.csv
# 1531_高林股 Kaulin.csv saving success.
# Saving 1533_車王電 MORE.csv
# 1533_車王電 MORE.csv saving success.
# Saving 1535_中宇 CEC.csv
# 1535_中宇 CEC.csv saving success.
# Saving 1536_和大 HOTA.csv
# 1536_和大 HOTA.csv saving success.
# Saving 1537_廣隆光電 KUNG LONG.csv
# 1537_廣隆光電 KUNG LONG.csv saving success.
# Saving 1539_巨庭機械 GEETECH.csv
# 1539_巨庭機械 GEETECH.csv saving success.
# Saving 1540_喬福機械 JOHNFORD.csv
# 1540_喬福機械 JOHNFORD.csv saving success.
# Saving 1541_錩泰 Chang Type.csv
# 1541_錩泰 Chang Type.csv saving success.
# Saving 1560_中砂 KINIK.csv
# 1560_中砂 KINIK.csv saving success.
# Saving 1583_程泰 GOODWAY.csv
# 1583_程泰 GOODWAY.csv saving success.
# Saving 2049_上銀科技 HIWIN.csv
# 2049_上銀科技 HIWIN.csv saving success.
# Saving 4526_東台 TOPPER.csv
# 4526_東台 TOPPER.csv saving success.
# Saving 4532_瑞智 RECHI.csv
# 4532_瑞智 RECHI.csv saving success.
# Saving 6605_帝寶 DEPO.csv
# 6605_帝寶 DEPO.csv saving success.
# Saving 8374_羅昇 ACE PILLAR.csv
# 8374_羅昇 ACE PILLAR.csv saving success.
# Saving 1603_中華電纜 CWCO.csv
# 1603_中華電纜 CWCO.csv saving success.
# Saving 1605_華新麗華 WALSIN.csv
# 1605_華新麗華 WALSIN.csv saving success.
# Saving 1608_華榮 HE.csv
# 1608_華榮 HE.csv saving success.
# Saving 1609_大亞電纜 TA YA.csv
# 1609_大亞電纜 TA YA.csv saving success.
# Saving 1611_中國電器 CE.csv
# 1611_中國電器 CE.csv saving success.
# Saving 1612_宏泰電工 Hong Tai.csv
# 1612_宏泰電工 Hong Tai.csv saving success.
# Saving 1614_三洋電機 SANYO.csv
# 1614_三洋電機 SANYO.csv saving success.
# Saving 1615_大山電纜 Dah San.csv
# 1615_大山電纜 Dah San.csv saving success.
# Saving 1616_億泰電纜 Evertop.csv
# 1616_億泰電纜 Evertop.csv saving success.
# Saving 1617_榮星電線 JSW.csv
# 1617_榮星電線 JSW.csv saving success.
# Saving 1618_合機電纜 Hold-Key.csv
# 1618_合機電纜 Hold-Key.csv saving success.
# Saving 1802_臺灣玻璃 Taiwan Glass.csv
# 1802_臺灣玻璃 Taiwan Glass.csv saving success.
# Saving 1806_冠軍 CHAMPION.csv
# 1806_冠軍 CHAMPION.csv saving success.
# Saving 1809_中國製釉 China Glaze.csv
# 1809_中國製釉 China Glaze.csv saving success.
# Saving 1810_和成欣業 HCG.csv
# 1810_和成欣業 HCG.csv saving success.
# Saving 1902_台灣紙業 TPPC.csv
# 1902_台灣紙業 TPPC.csv saving success.
# Saving 1903_士林紙業 Shihlin Paper.csv
# 1903_士林紙業 Shihlin Paper.csv saving success.
# Saving 1904_正隆 Cheng Loong.csv
# 1904_正隆 Cheng Loong.csv saving success.
# Saving 1905_中華紙漿 CHP.csv
# 1905_中華紙漿 CHP.csv saving success.
# Saving 1906_寶隆 P.L.csv
# 1906_寶隆 P.L.csv saving success.
# Saving 1907_永豐餘 YFY.csv
# 1907_永豐餘 YFY.csv saving success.
# Saving 1909_榮成紙業 LCP.csv
# 1909_榮成紙業 LCP.csv saving success.
# Saving 1532_勤美 CMP.csv
# 1532_勤美 CMP.csv saving success.
# Saving 2002A_中國鋼鐵        (特 別) China Steel preferred.csv
# 2002A_中國鋼鐵        (特 別) China Steel preferred.csv saving success.
# Saving 2006_東和鋼鐵 Tung Ho Steel.csv
# 2006_東和鋼鐵 Tung Ho Steel.csv saving success.
# Saving 2007_燁興 YH.csv
# 2007_燁興 YH.csv saving success.
# Saving 2009_第一伸銅 First Copper Technology.csv
# 2009_第一伸銅 First Copper Technology.csv saving success.
# Saving 2010_春源鋼鐵 Chun Yuan Steel.csv
# 2010_春源鋼鐵 Chun Yuan Steel.csv saving success.
# Saving 2012_春雨工廠 Chun Yu.csv
# 2012_春雨工廠 Chun Yu.csv saving success.
# Saving 2013_中鋼構 CSSC.csv
# 2013_中鋼構 CSSC.csv saving success.
# Saving 2015_豐興鋼鐵 FH.csv
# 2015_豐興鋼鐵 FH.csv saving success.
# Saving 2017_官田鋼 Quintain Steel.csv
# 2017_官田鋼 Quintain Steel.csv saving success.
# Saving 2020_美亞 MAYER PIPE.csv
# 2020_美亞 MAYER PIPE.csv saving success.
# Saving 2022_聚亨 TYCOONS.csv
# 2022_聚亨 TYCOONS.csv saving success.
# Saving 2023_燁輝 YP.csv
# 2023_燁輝 YP.csv saving success.
# Saving 2024_志聯工業 CHIH LIEN.csv
# 2024_志聯工業 CHIH LIEN.csv saving success.
# Saving 2027_大成鋼 TC.csv
# 2027_大成鋼 TC.csv saving success.
# Saving 2029_盛餘 Sheng Yu Steel.csv
# 2029_盛餘 Sheng Yu Steel.csv saving success.
# Saving 2030_彰源 FROCH.csv
# 2030_彰源 FROCH.csv saving success.
# Saving 2031_新光鋼鐵 Hsin Kuang Steel.csv
# 2031_新光鋼鐵 Hsin Kuang Steel.csv saving success.
# Saving 2032_新鋼工業 Sinkang.csv
# 2032_新鋼工業 Sinkang.csv saving success.
# Saving 2033_佳大世界 Chia Ta.csv
# 2033_佳大世界 Chia Ta.csv saving success.
# Saving 2034_允強 Yeun Chyang Industrial.csv
# 2034_允強 Yeun Chyang Industrial.csv saving success.
# Saving 2038_海光企業 HAIKWANG.csv
# 2038_海光企業 HAIKWANG.csv saving success.
# Saving 9958_世紀鋼 CIAS.csv
# 9958_世紀鋼 CIAS.csv saving success.
# Saving 2101_南港輪胎 Nan Kang Rubber Tire.csv
# 2101_南港輪胎 Nan Kang Rubber Tire.csv saving success.
# Saving 2102_泰豐輪胎 FEDERAL CORP.csv
# 2102_泰豐輪胎 FEDERAL CORP.csv saving success.
# Saving 2103_台橡 TSRC.csv
# 2103_台橡 TSRC.csv saving success.
# Saving 2104_中國橡膠 China Synthetic Rubber.csv
# 2104_中國橡膠 China Synthetic Rubber.csv saving success.
# Saving 2105_正新橡膠 CST.csv
# 2105_正新橡膠 CST.csv saving success.
# Saving 2106_建大工業 Kenda Rubber Ind..csv
# 2106_建大工業 Kenda Rubber Ind..csv saving success.
# Saving 2107_厚生 Formosan Rubber Group.csv
# 2107_厚生 Formosan Rubber Group.csv saving success.
# Saving 2108_南帝化工 Nantex.csv
# 2108_南帝化工 Nantex.csv saving success.
# Saving 2109_華豐橡膠 Hwa Fong.csv
# 2109_華豐橡膠 Hwa Fong.csv saving success.
# Saving 2201_裕隆汽車 Yulon Motor.csv
# 2201_裕隆汽車 Yulon Motor.csv saving success.
# Saving 2204_中華汽車 China-Motor.csv
# 2204_中華汽車 China-Motor.csv saving success.
# Saving 2206_三陽工業 Sanyang Industry.csv
# 2206_三陽工業 Sanyang Industry.csv saving success.
# Saving 2207_和泰汽車 Hotai Motor.csv
# 2207_和泰汽車 Hotai Motor.csv saving success.
# Saving 2227_裕日車 YNM.csv
# 2227_裕日車 YNM.csv saving success.
# Saving 1436_福益 FUI.csv
# 1436_福益 FUI.csv saving success.
# Saving 1442_名軒 ADVANCETEK.csv
# 1442_名軒 ADVANCETEK.csv saving success.
# Saving 1808_國賓大 KOBIN.csv
# 1808_國賓大 KOBIN.csv saving success.
# Saving 2501_國建 Cathay Const..csv
# 2501_國建 Cathay Const..csv saving success.
# Saving 2504_國產 CATHAYRED GDC.csv
# 2504_國產 CATHAYRED GDC.csv saving success.
# Saving 2505_國揚 Ky.csv
# 2505_國揚 Ky.csv saving success.
# Saving 2509_全坤建 CHAINQUI.csv
# 2509_全坤建 CHAINQUI.csv saving success.
# Saving 2511_太子 PHD.csv
# 2511_太子 PHD.csv saving success.
# Saving 2515_中工 BES.csv
# 2515_中工 BES.csv saving success.
# Saving 2516_新建 New Asia.csv
# 2516_新建 New Asia.csv saving success.
# Saving 2520_冠德 Kindom.csv
# 2520_冠德 Kindom.csv saving success.
# Saving 2524_京城 KTC.csv
# 2524_京城 KTC.csv saving success.
# Saving 2527_宏璟 Hung Ching.csv
# 2527_宏璟 Hung Ching.csv saving success.
# Saving 2530_華建 Delpha Construction.csv
# 2530_華建 Delpha Construction.csv saving success.
# Saving 2534_宏盛 HSC.csv
# 2534_宏盛 HSC.csv saving success.
# Saving 2535_達欣工 DA CIN.csv
# 2535_達欣工 DA CIN.csv saving success.
# Saving 2536_宏普 Hung Poo.csv
# 2536_宏普 Hung Poo.csv saving success.
# Saving 2537_聯上開發 WE &WIN.csv
# 2537_聯上開發 WE &WIN.csv saving success.
# Saving 2538_基泰 Kee Tai.csv
# 2538_基泰 Kee Tai.csv saving success.
# Saving 2539_櫻建 SAKURAD.csv
# 2539_櫻建 SAKURAD.csv saving success.
# Saving 2542_興富發 Highwealth.csv
# 2542_興富發 Highwealth.csv saving success.
# Saving 2543_皇昌 Hwang Chang.csv
# 2543_皇昌 Hwang Chang.csv saving success.
# Saving 2545_皇翔 Huang Hsiang.csv
# 2545_皇翔 Huang Hsiang.csv saving success.
# Saving 2546_根基 Kedge.csv
# 2546_根基 Kedge.csv saving success.
# Saving 2547_日勝生 Radium.csv
# 2547_日勝生 Radium.csv saving success.
# Saving 2548_華固 HUAKU.csv
# 2548_華固 HUAKU.csv saving success.
# Saving 2841_台開 TDC.csv
# 2841_台開 TDC.csv saving success.
# Saving 5515_建國 CHIEN KUO.csv
# 5515_建國 CHIEN KUO.csv saving success.
# Saving 5522_遠雄建設 Farglory.csv
# 5522_遠雄建設 Farglory.csv saving success.
# Saving 5525_順天 SWEETEN.csv
# 5525_順天 SWEETEN.csv saving success.
# Saving 5531_鄉林建設 SHINING.csv
# 5531_鄉林建設 SHINING.csv saving success.
# Saving 5533_皇鼎建設 FOUNDING.csv
# 5533_皇鼎建設 FOUNDING.csv saving success.
# Saving 5534_長虹 CHONG HONG.csv
# 5534_長虹 CHONG HONG.csv saving success.
# Saving 2208_台船公司 CSBC.csv
# 2208_台船公司 CSBC.csv saving success.
# Saving 2601_益航 FSC.csv
# 2601_益航 FSC.csv saving success.
# Saving 2603_長榮 EMC.csv
# 2603_長榮 EMC.csv saving success.
# Saving 2605_新興 SNC.csv
# 2605_新興 SNC.csv saving success.
# Saving 2606_裕民 U-Ming.csv
# 2606_裕民 U-Ming.csv saving success.
# Saving 2607_榮運 EITC.csv
# 2607_榮運 EITC.csv saving success.
# Saving 2608_大榮 T.JOIN.csv
# 2608_大榮 T.JOIN.csv saving success.
# Saving 2609_陽明 YMTC.csv
# 2609_陽明 YMTC.csv saving success.
# Saving 2610_華航 CAL.csv
# 2610_華航 CAL.csv saving success.
# Saving 2611_志信 TSI.csv
# 2611_志信 TSI.csv saving success.
# Saving 2612_中航 CMT.csv
# 2612_中航 CMT.csv saving success.
# Saving 2613_中櫃 CCTC.csv
# 2613_中櫃 CCTC.csv saving success.
# Saving 2614_東森科 EMIC.csv
# 2614_東森科 EMIC.csv saving success.
# Saving 2615_萬海 WANHAI.csv
# 2615_萬海 WANHAI.csv saving success.
# Saving 2617_台航 TAIWANLINE.csv
# 2617_台航 TAIWANLINE.csv saving success.
# Saving 2618_長榮航 EVAAIR.csv
# 2618_長榮航 EVAAIR.csv saving success.
# Saving 5607_遠雄港 Farglory FTZ.csv
# 5607_遠雄港 Farglory FTZ.csv saving success.
# Saving 5608_四維航 S. W..csv
# 5608_四維航 S. W..csv saving success.
# Saving 2701_萬企 WANHWA.csv
# 2701_萬企 WANHWA.csv saving success.
# Saving 2702_華園 HG.csv
# 2702_華園 HG.csv saving success.
# Saving 2704_國賓 AMBH.csv
# 2704_國賓 AMBH.csv saving success.
# Saving 2705_六福 LEOFOO.csv
# 2705_六福 LEOFOO.csv saving success.
# Saving 2706_第一店 First Hotel.csv
# 2706_第一店 First Hotel.csv saving success.
# Saving 2707_晶華酒店 GFRT.csv
# 2707_晶華酒店 GFRT.csv saving success.
# Saving 8940_新天地 New Palace.csv
# 8940_新天地 New Palace.csv saving success.
# Saving 2801_彰銀 C.H.B.csv
# 2801_彰銀 C.H.B.csv saving success.
# Saving 2809_京城銀 KTB.csv
# 2809_京城銀 KTB.csv saving success.
# Saving 2812_中商銀 TCCB.csv
# 2812_中商銀 TCCB.csv saving success.
# Saving 2816_旺旺保險 UNION INS..csv
# 2816_旺旺保險 UNION INS..csv saving success.
# Saving 2820_華票 CBF.csv
# 2820_華票 CBF.csv saving success.
# Saving 2823_中國人壽 CHINA LIFE.csv
# 2823_中國人壽 CHINA LIFE.csv saving success.
# Saving 2832_台灣產物 TFMI.csv
# 2832_台灣產物 TFMI.csv saving success.
# Saving 2834_台灣企銀 TBB.csv
# 2834_台灣企銀 TBB.csv saving success.
# Saving 2836_高雄銀行 B.O.K.csv
# 2836_高雄銀行 B.O.K.csv saving success.
# Saving 2845_遠東商銀 FEIB.csv
# 2845_遠東商銀 FEIB.csv saving success.
# Saving 2849_安泰商銀 ETB.csv
# 2849_安泰商銀 ETB.csv saving success.
# Saving 2850_新光產險 SK Insurance.csv
# 2850_新光產險 SK Insurance.csv saving success.
# Saving 2851_中再保 C.R.C..csv
# 2851_中再保 C.R.C..csv saving success.
# Saving 2852_第一保 First Ins..csv
# 2852_第一保 First Ins..csv saving success.
# Saving 2855_統一證券 PSC.csv
# 2855_統一證券 PSC.csv saving success.
# Saving 2880_華南金 HNFHC.csv
# 2880_華南金 HNFHC.csv saving success.
# Saving 2883_開發金 CDIBH.csv
# 2883_開發金 CDIBH.csv saving success.
# Saving 2884_玉山金 E.SUN FHC.csv
# 2884_玉山金 E.SUN FHC.csv saving success.
# Saving 2885_元大金 Yuanta Group.csv
# 2885_元大金 Yuanta Group.csv saving success.
# Saving 2886_兆豐金 MEGA FHC.csv
# 2886_兆豐金 MEGA FHC.csv saving success.
# Saving 2889_國票金 Waterland Holdings.csv
# 2889_國票金 Waterland Holdings.csv saving success.
# Saving 2890_永豐金控 SINOPACHOLDINGS.csv
# 2890_永豐金控 SINOPACHOLDINGS.csv saving success.
# Saving 2892_第一金 FFHC.csv
# 2892_第一金 FFHC.csv saving success.
# Saving 6005_群益證 CSC.csv
# 6005_群益證 CSC.csv saving success.
# Saving 2901_欣欣大眾 Shin Shin.csv
# 2901_欣欣大眾 Shin Shin.csv saving success.
# Saving 2903_遠東百貨 FEDS.csv
# 2903_遠東百貨 FEDS.csv saving success.
# Saving 2905_三 商 行 Mercuries.csv
# 2905_三 商 行 Mercuries.csv saving success.
# Saving 2906_高林實業 Collins.csv
# 2906_高林實業 Collins.csv saving success.
# Saving 2908_特力 Test Rite.csv
# 2908_特力 Test Rite.csv saving success.
# Saving 2910_統領百貨 TONLIN.csv
# 2910_統領百貨 TONLIN.csv saving success.
# Saving 2911_麗嬰房 LES.csv
# 2911_麗嬰房 LES.csv saving success.
# Saving 2912_統一超商 PCSC.csv
# 2912_統一超商 PCSC.csv saving success.
# Saving 2913_臺灣農林 TTC.csv
# 2913_臺灣農林 TTC.csv saving success.
# Saving 2915_潤泰全球 RUENTEX IND. LTD.csv
# 2915_潤泰全球 RUENTEX IND. LTD.csv saving success.
# Saving 1708_東鹼 Sesoda.csv
# 1708_東鹼 Sesoda.csv saving success.
# Saving 1709_和益化工 FUCC.csv
# 1709_和益化工 FUCC.csv saving success.
# Saving 1710_東聯化學 OUCC.csv
# 1710_東聯化學 OUCC.csv saving success.
# Saving 1711_永光化學 EVERLIGHT.csv
# 1711_永光化學 EVERLIGHT.csv saving success.
# Saving 1712_興農 Sinon.csv
# 1712_興農 Sinon.csv saving success.
# Saving 1713_國泰化工 Cathay Chemical.csv
# 1713_國泰化工 Cathay Chemical.csv saving success.
# Saving 1714_和桐化學 HO TUNG.csv
# 1714_和桐化學 HO TUNG.csv saving success.
# Saving 1717_長興化學 ETERNAL.csv
# 1717_長興化學 ETERNAL.csv saving success.
# Saving 1718_中國人纖 CMFC.csv
# 1718_中國人纖 CMFC.csv saving success.
# Saving 1721_三晃 Sunko Ink.csv
# 1721_三晃 Sunko Ink.csv saving success.
# Saving 1722_台灣肥料 Taiwan Fertilizer.csv
# 1722_台灣肥料 Taiwan Fertilizer.csv saving success.
# Saving 1723_中鋼碳素 CSCC.csv
# 1723_中鋼碳素 CSCC.csv saving success.
# Saving 1724_台硝 T.N.C..csv
# 1724_台硝 T.N.C..csv saving success.
# Saving 1725_元禎 YJE.csv
# 1725_元禎 YJE.csv saving success.
# Saving 1726_永記造漆 YCP.csv
# 1726_永記造漆 YCP.csv saving success.
# Saving 1727_中華化 CHCIW.csv
# 1727_中華化 CHCIW.csv saving success.
# Saving 1730_花仙子 FARCENT.csv
# 1730_花仙子 FARCENT.csv saving success.
# Saving 1732_毛寶 Mao Bao.csv
# 1732_毛寶 Mao Bao.csv saving success.
# Saving 1735_日勝化工 EMC.csv
# 1735_日勝化工 EMC.csv saving success.
# Saving 1737_臺鹽 TAIYEN.csv
# 1737_臺鹽 TAIYEN.csv saving success.
# Saving 1773_勝一化工 SHINY.csv
# 1773_勝一化工 SHINY.csv saving success.
# Saving 4725_信昌化工 TPCC.csv
# 4725_信昌化工 TPCC.csv saving success.
# Saving 1701_中國化學 CCPC.csv
# 1701_中國化學 CCPC.csv saving success.
# Saving 1707_葡萄王 Grape King.csv
# 1707_葡萄王 Grape King.csv saving success.
# Saving 1720_生達化學 S.C.P.C.csv
# 1720_生達化學 S.C.P.C.csv saving success.
# Saving 1731_美吾華 Maywufa.csv
# 1731_美吾華 Maywufa.csv saving success.
# Saving 1733_五鼎 ApexBio.csv
# 1733_五鼎 ApexBio.csv saving success.
# Saving 1734_杏輝藥品 SINPHAR.csv
# 1734_杏輝藥品 SINPHAR.csv saving success.
# Saving 1736_喬山 JHT.csv
# 1736_喬山 JHT.csv saving success.
# Saving 4104_佳醫 EXCELSIOR.csv
# 4104_佳醫 EXCELSIOR.csv saving success.
# Saving 4106_雃博 APEX.csv
# 4106_雃博 APEX.csv saving success.
# Saving 4108_懷特 PhytoHealth.csv
# 4108_懷特 PhytoHealth.csv saving success.
# Saving 4119_旭富 SCI.csv
# 4119_旭富 SCI.csv saving success.
# Saving 4133_亞諾法 Abnova.csv
# 4133_亞諾法 Abnova.csv saving success.
# Saving 2616_山隆 SLC.csv
# 2616_山隆 SLC.csv saving success.
# Saving 6505_台塑化 FPCC.csv
# 6505_台塑化 FPCC.csv saving success.
# Saving 8926_台汽電 TCC.csv
# 8926_台汽電 TCC.csv saving success.
# Saving 9908_大台北瓦斯 GTG.csv
# 9908_大台北瓦斯 GTG.csv saving success.
# Saving 9918_欣天然 S.S.N.G..csv
# 9918_欣天然 S.S.N.G..csv saving success.
# Saving 9926_新海瓦斯 S.H..csv
# 9926_新海瓦斯 S.H..csv saving success.
# Saving 9931_欣高 Hsin Kao.csv
# 9931_欣高 Hsin Kao.csv saving success.
# Saving 9937_全國加油站 NPC.csv
# 9937_全國加油站 NPC.csv saving success.
# Saving 1437_勤益 GTM.csv
# 1437_勤益 GTM.csv saving success.
# Saving 2302_麗正 Rectron.csv
# 2302_麗正 Rectron.csv saving success.
# Saving 2303_聯電 UMC.csv
# 2303_聯電 UMC.csv saving success.
# Saving 2329_華泰 OSE.csv
# 2329_華泰 OSE.csv saving success.
# Saving 2330_台積電 TSMC.csv
# 2330_台積電 TSMC.csv saving success.
# Saving 2338_光罩 TMC.csv
# 2338_光罩 TMC.csv saving success.
# Saving 2344_華邦電 WEC.csv
# 2344_華邦電 WEC.csv saving success.
# Saving 2351_順德 SDI Corporation.csv
# 2351_順德 SDI Corporation.csv saving success.
# Saving 2363_矽統 SiS.csv
# 2363_矽統 SiS.csv saving success.
# Saving 2369_菱生 LPI.csv
# 2369_菱生 LPI.csv saving success.
# Saving 2379_瑞昱 RT.csv
# 2379_瑞昱 RT.csv saving success.
# Saving 2401_凌陽 Sunplus.csv
# 2401_凌陽 Sunplus.csv saving success.
# Saving 2425_承啟 CHAINTECH.csv
# 2425_承啟 CHAINTECH.csv saving success.
# Saving 2436_偉詮電 Weltrend.csv
# 2436_偉詮電 Weltrend.csv saving success.
# Saving 2441_超豐 GTK.csv
# 2441_超豐 GTK.csv saving success.
# Saving 2449_京元電 KYEC.csv
# 2449_京元電 KYEC.csv saving success.
# Saving 2451_創見 Transcend.csv
# 2451_創見 Transcend.csv saving success.
# Saving 2454_聯發科 MediaTek.csv
# 2454_聯發科 MediaTek.csv saving success.
# Saving 2458_義隆 Elan.csv
# 2458_義隆 Elan.csv saving success.
# Saving 2481_強茂 Pan Jit.csv
# 2481_強茂 Pan Jit.csv saving success.
# Saving 3006_晶豪科 ESMT.csv
# 3006_晶豪科 ESMT.csv saving success.
# Saving 3014_聯陽 ITE.csv
# 3014_聯陽 ITE.csv saving success.
# Saving 3016_嘉晶 PRECISION.csv
# 3016_嘉晶 PRECISION.csv saving success.
# Saving 3034_聯詠 NOVATEK.csv
# 3034_聯詠 NOVATEK.csv saving success.
# Saving 3035_智原 Faraday.csv
# 3035_智原 Faraday.csv saving success.
# Saving 3041_揚智 Ali.csv
# 3041_揚智 Ali.csv saving success.
# Saving 3056_駿億 KB.csv
# 3056_駿億 KB.csv saving success.
# Saving 3094_聯傑國際 DAVICOM.csv
# 3094_聯傑國際 DAVICOM.csv saving success.
# Saving 3189_景碩 KINSUS.csv
# 3189_景碩 KINSUS.csv saving success.
# Saving 3443_創意 GUC.csv
# 3443_創意 GUC.csv saving success.
# Saving 3532_台勝科 FST.csv
# 3532_台勝科 FST.csv saving success.
# Saving 3545_旭曜 Orisetech.csv
# 3545_旭曜 Orisetech.csv saving success.
# Saving 3588_通嘉 LD.csv
# 3588_通嘉 LD.csv saving success.
# Saving 5471_松翰 SONIX.csv
# 5471_松翰 SONIX.csv saving success.
# Saving 6202_盛群 HOLTEK.csv
# 6202_盛群 HOLTEK.csv saving success.
# Saving 6239_力成 PTI.csv
# 6239_力成 PTI.csv saving success.
# Saving 6243_迅杰 ENE.csv
# 6243_迅杰 ENE.csv saving success.
# Saving 6257_矽格 SIGURD.csv
# 6257_矽格 SIGURD.csv saving success.
# Saving 6271_同欣電子 THEIL.csv
# 6271_同欣電子 THEIL.csv saving success.
# Saving 8016_矽創 Sitronix.csv
# 8016_矽創 Sitronix.csv saving success.
# Saving 8081_致新 GMT.csv
# 8081_致新 GMT.csv saving success.
# Saving 8110_華東科技 WALTON.csv
# 8110_華東科技 WALTON.csv saving success.
# Saving 8131_福懋科技 FATC.csv
# 8131_福懋科技 FATC.csv saving success.
# Saving 8261_富鼎先進 APEC.csv
# 8261_富鼎先進 APEC.csv saving success.
# Saving 1604_聲寶 Sampo.csv
# 1604_聲寶 Sampo.csv saving success.
# Saving 2301_光寶科 LTC.csv
# 2301_光寶科 LTC.csv saving success.
# Saving 2305_全友 MII.csv
# 2305_全友 MII.csv saving success.
# Saving 2324_仁寶 Compal.csv
# 2324_仁寶 Compal.csv saving success.
# Saving 2331_精英 Elitegroup.csv
# 2331_精英 Elitegroup.csv saving success.
# Saving 2352_佳世達 Qisda.csv
# 2352_佳世達 Qisda.csv saving success.
# Saving 2353_宏碁 ACER.csv
# 2353_宏碁 ACER.csv saving success.
# Saving 2356_英業達 Inventec.csv
# 2356_英業達 Inventec.csv saving success.
# Saving 2357_華碩 Asustek.csv
# 2357_華碩 Asustek.csv saving success.
# Saving 2358_美格 MAG.csv
# 2358_美格 MAG.csv saving success.
# Saving 2362_藍天 CLEVO.csv
# 2362_藍天 CLEVO.csv saving success.
# Saving 2365_昆盈 KYE.csv
# 2365_昆盈 KYE.csv saving success.
# Saving 2376_技嘉 GIGABYTE.csv
# 2376_技嘉 GIGABYTE.csv saving success.
# Saving 2377_微星 MSI.csv
# 2377_微星 MSI.csv saving success.
# Saving 2380_虹光 Avision.csv
# 2380_虹光 Avision.csv saving success.
# Saving 2382_廣達 QCI.csv
# 2382_廣達 QCI.csv saving success.
# Saving 2385_群光 Chicony.csv
# 2385_群光 Chicony.csv saving success.
# Saving 2387_精元 Sunrex.csv
# 2387_精元 Sunrex.csv saving success.
# Saving 2395_研華 Advantech.csv
# 2395_研華 Advantech.csv saving success.
# Saving 2397_友通 DFI.csv
# 2397_友通 DFI.csv saving success.
# Saving 2399_映泰 Biostar.csv
# 2399_映泰 Biostar.csv saving success.
# Saving 2405_浩鑫 Shuttle.csv
# 2405_浩鑫 Shuttle.csv saving success.
# Saving 2417_圓剛 AVerMedia.csv
# 2417_圓剛 AVerMedia.csv saving success.
# Saving 2424_隴華 Lung Hwa.csv
# 2424_隴華 Lung Hwa.csv saving success.
# Saving 2442_美齊 Jean.csv
# 2442_美齊 Jean.csv saving success.
# Saving 2465_麗臺 Leadtek.csv
# 2465_麗臺 Leadtek.csv saving success.
# Saving 2474_可成 Catcher.csv
# 2474_可成 Catcher.csv saving success.
# Saving 3002_歐格 Ahoku.csv
# 3002_歐格 Ahoku.csv saving success.
# Saving 3005_神基 MTC.csv
# 3005_神基 MTC.csv saving success.
# Saving 3013_晟銘電 UNEEC.csv
# 3013_晟銘電 UNEEC.csv saving success.
# Saving 3017_奇鋐 AVC.csv
# 3017_奇鋐 AVC.csv saving success.
# Saving 3022_威達電 IEI.csv
# 3022_威達電 IEI.csv saving success.
# Saving 3054_萬國 CARRY.csv
# 3054_萬國 CARRY.csv saving success.
# Saving 3057_喬鼎 Promise..csv
# 3057_喬鼎 Promise..csv saving success.
# Saving 3060_銘異 MIN AIK.csv
# 3060_銘異 MIN AIK.csv saving success.
# Saving 3231_緯創 Wistron.csv
# 3231_緯創 Wistron.csv saving success.
# Saving 3494_誠研 HiTi.csv
# 3494_誠研 HiTi.csv saving success.
# Saving 3515_華擎 ASROCK.csv
# 3515_華擎 ASROCK.csv saving success.
# Saving 6117_迎廣 IN WIN.csv
# 6117_迎廣 IN WIN.csv saving success.
# Saving 6128_上福 GPI.csv
# 6128_上福 GPI.csv saving success.
# Saving 6166_凌華 ADLINK.csv
# 6166_凌華 ADLINK.csv saving success.
# Saving 6206_飛捷 FLYTECH.csv
# 6206_飛捷 FLYTECH.csv saving success.
# Saving 6235_華孚科技 Waffer.csv
# 6235_華孚科技 Waffer.csv saving success.
# Saving 6277_宏正 ATEN.csv
# 6277_宏正 ATEN.csv saving success.
# Saving 9912_偉聯科技 AIC.csv
# 9912_偉聯科技 AIC.csv saving success.
# Saving 2323_中環 CMC.csv
# 2323_中環 CMC.csv saving success.
# Saving 2340_光磊 OPTO.csv
# 2340_光磊 OPTO.csv saving success.
# Saving 2349_錸德 RITEK.csv
# 2349_錸德 RITEK.csv saving success.
# Saving 2374_佳能 Ability.csv
# 2374_佳能 Ability.csv saving success.
# Saving 2393_億光 Everlight.csv
# 2393_億光 Everlight.csv saving success.
# Saving 2406_國碩 Gigastorage.csv
# 2406_國碩 Gigastorage.csv saving success.
# Saving 2409_友達 AUO.csv
# 2409_友達 AUO.csv saving success.
# Saving 2426_鼎元 Tyntek.csv
# 2426_鼎元 Tyntek.csv saving success.
# Saving 2448_晶元 Epistar.csv
# 2448_晶元 Epistar.csv saving success.
# Saving 2466_冠西電 Cosmo.csv
# 2466_冠西電 Cosmo.csv saving success.
# Saving 2486_一詮 I-Chiun.csv
# 2486_一詮 I-Chiun.csv saving success.
# Saving 2489_瑞軒 Amtran.csv
# 2489_瑞軒 Amtran.csv saving success.
# Saving 2499_東貝 UNI.csv
# 2499_東貝 UNI.csv saving success.
# Saving 3008_大立光 LARGAN.csv
# 3008_大立光 LARGAN.csv saving success.
# Saving 3019_亞洲光學 ASIA.csv
# 3019_亞洲光學 ASIA.csv saving success.
# Saving 3024_憶聲 ACN.csv
# 3024_憶聲 ACN.csv saving success.
# Saving 3031_佰鴻 BRIGHT.csv
# 3031_佰鴻 BRIGHT.csv saving success.
# Saving 3038_全台 EDT.csv
# 3038_全台 EDT.csv saving success.
# Saving 3049_和鑫 SINTEK.csv
# 3049_和鑫 SINTEK.csv saving success.
# Saving 3050_鈺德 U-Tech.csv
# 3050_鈺德 U-Tech.csv saving success.
# Saving 3059_華晶科 Altek.csv
# 3059_華晶科 Altek.csv saving success.
# Saving 3406_玉晶光 GENIUS.csv
# 3406_玉晶光 GENIUS.csv saving success.
# Saving 3481_群創 INNOLUX.csv
# 3481_群創 INNOLUX.csv saving success.
# Saving 3504_揚明光 Young Optics.csv
# 3504_揚明光 Young Optics.csv saving success.
# Saving 3535_晶彩科 Favite.csv
# 3535_晶彩科 Favite.csv saving success.
# Saving 3557_嘉威光電 Gamma.csv
# 3557_嘉威光電 Gamma.csv saving success.
# Saving 3576_新日光 NSP.csv
# 3576_新日光 NSP.csv saving success.
# Saving 3593_力銘科技 logah.csv
# 3593_力銘科技 logah.csv saving success.
# Saving 3622_洋華 YFO.csv
# 3622_洋華 YFO.csv saving success.
# Saving 5305_敦南 LSC.csv
# 5305_敦南 LSC.csv saving success.
# Saving 5484_慧友 EverFocus.csv
# 5484_慧友 EverFocus.csv saving success.
# Saving 6120_輔祥 FORHOUSE.csv
# 6120_輔祥 FORHOUSE.csv saving success.
# Saving 6164_華興電子 LEDTECH.csv
# 6164_華興電子 LEDTECH.csv saving success.
# Saving 6168_宏齊 HARVATEK CORPOR.csv
# 6168_宏齊 HARVATEK CORPOR.csv saving success.
# Saving 6176_瑞儀 ROEC.csv
# 6176_瑞儀 ROEC.csv saving success.
# Saving 6209_今國光學 KINKO.csv
# 6209_今國光學 KINKO.csv saving success.
# Saving 6226_光鼎電子 Para Light.csv
# 6226_光鼎電子 Para Light.csv saving success.
# Saving 8072_陞泰科技 AV TECH.csv
# 8072_陞泰科技 AV TECH.csv saving success.
# Saving 8105_凌巨 GiantPlus.csv
# 8105_凌巨 GiantPlus.csv saving success.
# Saving 2314_台揚 MTI.csv
# 2314_台揚 MTI.csv saving success.
# Saving 2332_友訊 D-Link.csv
# 2332_友訊 D-Link.csv saving success.
# Saving 2345_智邦 Accton.csv
# 2345_智邦 Accton.csv saving success.
# Saving 2402_毅嘉 ICHIA.csv
# 2402_毅嘉 ICHIA.csv saving success.
# Saving 2412_中華電信 CHT.csv
# 2412_中華電信 CHT.csv saving success.
# Saving 2419_仲琦 Hitron.csv
# 2419_仲琦 Hitron.csv saving success.
# Saving 2439_美律 Merry.csv
# 2439_美律 Merry.csv saving success.
# Saving 2444_友旺 Abo-Com.csv
# 2444_友旺 Abo-Com.csv saving success.
# Saving 2450_神腦 Senao.csv
# 2450_神腦 Senao.csv saving success.
# Saving 2455_全新 VPEC.csv
# 2455_全新 VPEC.csv saving success.
# Saving 2485_兆赫 Zinwell.csv
# 2485_兆赫 Zinwell.csv saving success.
# Saving 2498_宏達電 HTC.csv
# 2498_宏達電 HTC.csv saving success.
# Saving 3025_星通 Loop.csv
# 3025_星通 Loop.csv saving success.
# Saving 3027_盛達 BILLION.csv
# 3027_盛達 BILLION.csv saving success.
# Saving 3045_台灣大哥大 TWM.csv
# 3045_台灣大哥大 TWM.csv saving success.
# Saving 3047_訊舟 EDIMAX.csv
# 3047_訊舟 EDIMAX.csv saving success.
# Saving 3062_建漢 CyberTAN.csv
# 3062_建漢 CyberTAN.csv saving success.
# Saving 3311_閎暉 Silitech.csv
# 3311_閎暉 Silitech.csv saving success.
# Saving 3380_明泰 Alpha.csv
# 3380_明泰 Alpha.csv saving success.
# Saving 3419_譁裕 WHAYU.csv
# 3419_譁裕 WHAYU.csv saving success.
# Saving 3596_智易科技 Arcadyan.csv
# 3596_智易科技 Arcadyan.csv saving success.
# Saving 4904_遠傳 Far EasTone.csv
# 4904_遠傳 Far EasTone.csv saving success.
# Saving 4906_正文 Gemtek.csv
# 4906_正文 Gemtek.csv saving success.
# Saving 5388_中磊 SERCOMM.csv
# 5388_中磊 SERCOMM.csv saving success.
# Saving 6136_富爾特 FTC.csv
# 6136_富爾特 FTC.csv saving success.
# Saving 6142_友勁 CAMEO.csv
# 6142_友勁 CAMEO.csv saving success.
# Saving 6152_百一 PRIME.csv
# 6152_百一 PRIME.csv saving success.
# Saving 6216_居易 Draytek Corp..csv
# 6216_居易 Draytek Corp..csv saving success.
# Saving 6283_淳安電子 SOE.csv
# 6283_淳安電子 SOE.csv saving success.
# Saving 6285_啟碁 WNC.csv
# 6285_啟碁 WNC.csv saving success.
# Saving 8101_華冠 Arima Comm..csv
# 8101_華冠 Arima Comm..csv saving success.
# Saving 1582_信錦 SYNCMOLD.csv
# 1582_信錦 SYNCMOLD.csv saving success.
# Saving 2059_川湖 king slide.csv
# 2059_川湖 king slide.csv saving success.
# Saving 2308_台達電 Delta Electronics.csv
# 2308_台達電 Delta Electronics.csv saving success.
# Saving 2313_華通 COMPEQ MFG..csv
# 2313_華通 COMPEQ MFG..csv saving success.
# Saving 2316_楠梓電 WUS.csv
# 2316_楠梓電 WUS.csv saving success.
# Saving 2327_國巨 Yageo.csv
# 2327_國巨 Yageo.csv saving success.
# Saving 2328_廣宇 Pan-International.csv
# 2328_廣宇 Pan-International.csv saving success.
# Saving 2355_敬鵬 Chin-Poon.csv
# 2355_敬鵬 Chin-Poon.csv saving success.
# Saving 2367_燿華 Unitech.csv
# 2367_燿華 Unitech.csv saving success.
# Saving 2368_金像 GCE.csv
# 2368_金像 GCE.csv saving success.
# Saving 2375_智寶 Teapo.csv
# 2375_智寶 Teapo.csv saving success.
# Saving 2383_台光電 EMC.csv
# 2383_台光電 EMC.csv saving success.
# Saving 2392_正崴 FOXLINK.csv
# 2392_正崴 FOXLINK.csv saving success.
# Saving 2413_環科 UMEC.csv
# 2413_環科 UMEC.csv saving success.
# Saving 2415_錩新 Cx Tech.csv
# 2415_錩新 Cx Tech.csv saving success.
# Saving 2420_新巨 Zippy.csv
# 2420_新巨 Zippy.csv saving success.
# Saving 2421_建準 Sunon.csv
# 2421_建準 Sunon.csv saving success.
# Saving 2428_興勤 TKS.csv
# 2428_興勤 TKS.csv saving success.
# Saving 2431_聯昌 Lien Chang.csv
# 2431_聯昌 Lien Chang.csv saving success.
# Saving 2440_太空梭 Space Shuttle.csv
# 2440_太空梭 Space Shuttle.csv saving success.
# Saving 2456_奇力新 Chilisin.csv
# 2456_奇力新 Chilisin.csv saving success.
# Saving 2457_飛宏 Phihong.csv
# 2457_飛宏 Phihong.csv saving success.
# Saving 2460_建通 Gem.csv
# 2460_建通 Gem.csv saving success.
# Saving 2462_良得電 LINETEK.csv
# 2462_良得電 LINETEK.csv saving success.
# Saving 2467_志聖 C Sun.csv
# 2467_志聖 C Sun.csv saving success.
# Saving 2472_立隆電 LEION.csv
# 2472_立隆電 LEION.csv saving success.
# Saving 2476_鉅祥 GS.csv
# 2476_鉅祥 GS.csv saving success.
# Saving 2478_大毅 Ta-I.csv
# 2478_大毅 Ta-I.csv saving success.
# Saving 2483_百容 ECE.csv
# 2483_百容 ECE.csv saving success.
# Saving 2484_希華 Siward.csv
# 2484_希華 Siward.csv saving success.
# Saving 2492_華新科 WTC.csv
# 2492_華新科 WTC.csv saving success.
# Saving 2493_揚博 AMPOC.csv
# 2493_揚博 AMPOC.csv saving success.
# Saving 3003_健和興 KST.csv
# 3003_健和興 KST.csv saving success.
# Saving 3011_今皓 JH.csv
# 3011_今皓 JH.csv saving success.
# Saving 3015_全漢 SPI.csv
# 3015_全漢 SPI.csv saving success.
# Saving 3023_信邦 SINBON.csv
# 3023_信邦 SINBON.csv saving success.
# Saving 3026_禾伸堂 HOLY  STONE.csv
# 3026_禾伸堂 HOLY  STONE.csv saving success.
# Saving 3032_偉訓 COMPUCASE.csv
# 3032_偉訓 COMPUCASE.csv saving success.
# Saving 3037_欣興 Unimicron.csv
# 3037_欣興 Unimicron.csv saving success.
# Saving 3042_晶技 TXC.csv
# 3042_晶技 TXC.csv saving success.
# Saving 3044_健鼎 Tripod.csv
# 3044_健鼎 Tripod.csv saving success.
# Saving 3058_立德 Leader.csv
# 3058_立德 Leader.csv saving success.
# Saving 3090_日電貿 NDB.csv
# 3090_日電貿 NDB.csv saving success.
# Saving 3229_晟鈦 CHEER TIME.csv
# 3229_晟鈦 CHEER TIME.csv saving success.
# Saving 3296_勝德 POWERTECH.csv
# 3296_勝德 POWERTECH.csv saving success.
# Saving 3308_聯德電子 BESTEC.csv
# 3308_聯德電子 BESTEC.csv saving success.
# Saving 3376_新日興 SZS.csv
# 3376_新日興 SZS.csv saving success.
# Saving 3501_維熹科技 Well Shin.csv
# 3501_維熹科技 Well Shin.csv saving success.
# Saving 3533_嘉澤 LOTES.csv
# 3533_嘉澤 LOTES.csv saving success.
# Saving 3605_宏致電子 ACES.csv
# 3605_宏致電子 ACES.csv saving success.
# Saving 3607_谷崧精密 Coxon.csv
# 3607_谷崧精密 Coxon.csv saving success.
# Saving 3653_健策 JENTECH.csv
# 3653_健策 JENTECH.csv saving success.
# Saving 5469_瀚宇博德 Board.csv
# 5469_瀚宇博德 Board.csv saving success.
# Saving 6108_競國實業 APCB INC..csv
# 6108_競國實業 APCB INC..csv saving success.
# Saving 6115_鎰勝 I-SHENG.csv
# 6115_鎰勝 I-SHENG.csv saving success.
# Saving 6133_金橋 Golden Bridge.csv
# 6133_金橋 Golden Bridge.csv saving success.
# Saving 6141_柏承科技 Plotech.csv
# 6141_柏承科技 Plotech.csv saving success.
# Saving 6153_嘉聯益 Career Tech..csv
# 6153_嘉聯益 Career Tech..csv saving success.
# Saving 6155_鈞寶電子 KC.csv
# 6155_鈞寶電子 KC.csv saving success.
# Saving 6191_精成科技 GBM.csv
# 6191_精成科技 GBM.csv saving success.
# Saving 6205_詮欣 COXOC.csv
# 6205_詮欣 COXOC.csv saving success.
# Saving 6213_聯茂 ITEQ.csv
# 6213_聯茂 ITEQ.csv saving success.
# Saving 6224_聚鼎科技 PTTC..csv
# 6224_聚鼎科技 PTTC..csv saving success.
# Saving 6251_定穎電子 DYNAMIC.csv
# 6251_定穎電子 DYNAMIC.csv saving success.
# Saving 6269_台郡 FLEXIUM.csv
# 6269_台郡 FLEXIUM.csv saving success.
# Saving 6282_康舒 AcBel.csv
# 6282_康舒 AcBel.csv saving success.
# Saving 8039_台虹 TAIFLEX.csv
# 8039_台虹 TAIFLEX.csv saving success.
# Saving 8046_南電 N.P.C..csv
# 8046_南電 N.P.C..csv saving success.
# Saving 8103_瀚荃股份有限公司 CviLux.csv
# 8103_瀚荃股份有限公司 CviLux.csv saving success.
# Saving 8163_達方電子 DARFON.csv
# 8163_達方電子 DARFON.csv saving success.
# Saving 8213_志超 tpt.csv
# 8213_志超 tpt.csv saving success.
# Saving 8249_菱光科技 CREATIVE SENSOR INC..csv
# 8249_菱光科技 CREATIVE SENSOR INC..csv saving success.
# Saving 1435_中福振業 Chun Fu.csv
# 1435_中福振業 Chun Fu.csv saving success.
# Saving 2347_聯強 Synnex.csv
# 2347_聯強 Synnex.csv saving success.
# Saving 2359_所羅門 Solomon.csv
# 2359_所羅門 Solomon.csv saving success.
# Saving 2414_精技 UTE.csv
# 2414_精技 UTE.csv saving success.
# Saving 2430_燦坤 TKE.csv
# 2430_燦坤 TKE.csv saving success.
# Saving 2459_敦吉 Audix.csv
# 2459_敦吉 Audix.csv saving success.
# Saving 3010_華立 Wahlee.csv
# 3010_華立 Wahlee.csv saving success.
# Saving 3028_增你強 Zenitron.csv
# 3028_增你強 Zenitron.csv saving success.
# Saving 3033_威健 WEIKENG.csv
# 3033_威健 WEIKENG.csv saving success.
# Saving 3036_文曄 Wintech.csv
# 3036_文曄 Wintech.csv saving success.
# Saving 3040_遠見 GV.csv
# 3040_遠見 GV.csv saving success.
# Saving 3048_益登 EDOM.csv
# 3048_益登 EDOM.csv saving success.
# Saving 3055_蔚華科 SPIROX.csv
# 3055_蔚華科 SPIROX.csv saving success.
# Saving 3209_全科科技 ALLTEK.csv
# 3209_全科科技 ALLTEK.csv saving success.
# Saving 5434_崇越 TOPCO.csv
# 5434_崇越 TOPCO.csv saving success.
# Saving 6189_豐藝 Promate.csv
# 6189_豐藝 Promate.csv saving success.
# Saving 6281_全國電 E-LIFE MALL.csv
# 6281_全國電 E-LIFE MALL.csv saving success.
# Saving 8070_長華電材 CHANG WAH.csv
# 8070_長華電材 CHANG WAH.csv saving success.
# Saving 8112_至上 Supreme.csv
# 8112_至上 Supreme.csv saving success.
# Saving 2427_三商電 MDS.csv
# 2427_三商電 MDS.csv saving success.
# Saving 2453_凌群 SYSCOM.csv
# 2453_凌群 SYSCOM.csv saving success.
# Saving 2468_華經 FIS.csv
# 2468_華經 FIS.csv saving success.
# Saving 2471_資通 ARES.csv
# 2471_資通 ARES.csv saving success.
# Saving 2480_敦陽科 Stark.csv
# 2480_敦陽科 Stark.csv saving success.
# Saving 3021_衛展資訊 WELLTEND.csv
# 3021_衛展資訊 WELLTEND.csv saving success.
# Saving 3029_零壹 ZERO ONE.csv
# 3029_零壹 ZERO ONE.csv saving success.
# Saving 3130_一零四 104 CORPORATION.csv
# 3130_一零四 104 CORPORATION.csv saving success.
# Saving 3356_奇偶科技 GeoVision.csv
# 3356_奇偶科技 GeoVision.csv saving success.
# Saving 5203_訊連 CyberLink.csv
# 5203_訊連 CyberLink.csv saving success.
# Saving 6112_聚碩 SYSAGE.csv
# 6112_聚碩 SYSAGE.csv saving success.
# Saving 2312_金寶 Kinpo Electronics.csv
# 2312_金寶 Kinpo Electronics.csv saving success.
# Saving 2317_鴻海 Hon Hai.csv
# 2317_鴻海 Hon Hai.csv saving success.
# Saving 2354_鴻準 FoxconnTechnology.csv
# 2354_鴻準 FoxconnTechnology.csv saving success.
# Saving 2360_致茂 Chroma.csv
# 2360_致茂 Chroma.csv saving success.
# Saving 2371_大同 Tatung.csv
# 2371_大同 Tatung.csv saving success.
# Saving 2373_震旦行 Aurora.csv
# 2373_震旦行 Aurora.csv saving success.
# Saving 2390_云辰 Everspring.csv
# 2390_云辰 Everspring.csv saving success.
# Saving 2404_漢唐 UIS.csv
# 2404_漢唐 UIS.csv saving success.
# Saving 2423_固緯 GW.csv
# 2423_固緯 GW.csv saving success.
# Saving 2433_互盛電 ASC.csv
# 2433_互盛電 ASC.csv saving success.
# Saving 2461_光群雷 K Laser.csv
# 2461_光群雷 K Laser.csv saving success.
# Saving 2464_盟立 Mirle.csv
# 2464_盟立 Mirle.csv saving success.
# Saving 2477_美隆電 Meiloon.csv
# 2477_美隆電 Meiloon.csv saving success.
# Saving 2482_連宇 UIC.csv
# 2482_連宇 UIC.csv saving success.
# Saving 2488_漢平 Hanpin.csv
# 2488_漢平 Hanpin.csv saving success.
# Saving 2495_普安 Infortrend.csv
# 2495_普安 Infortrend.csv saving success.
# Saving 2497_怡利電 E-LEAD.csv
# 2497_怡利電 E-LEAD.csv saving success.
# Saving 3018_同開 TUNG KAI.csv
# 3018_同開 TUNG KAI.csv saving success.
# Saving 3030_德律 TRI.csv
# 3030_德律 TRI.csv saving success.
# Saving 3052_夆典 APEX.csv
# 3052_夆典 APEX.csv saving success.
# Saving 3305_昇貿科技 SHENMAO.csv
# 3305_昇貿科技 SHENMAO.csv saving success.
# Saving 3450_聯鈞 ELASER.csv
# 3450_聯鈞 ELASER.csv saving success.
# Saving 3518_柏騰 PT TECH..csv
# 3518_柏騰 PT TECH..csv saving success.
# Saving 3617_碩天 CyberPower.csv
# 3617_碩天 CyberPower.csv saving success.
# Saving 6139_亞翔 L & K.csv
# 6139_亞翔 L & K.csv saving success.
# Saving 6192_巨路 LUMAX.csv
# 6192_巨路 LUMAX.csv saving success.
# Saving 6196_帆宣 MIC.csv
# 6196_帆宣 MIC.csv saving success.
# Saving 6197_佳必琪 JPC.csv
# 6197_佳必琪 JPC.csv saving success.
# Saving 6201_亞弘電 YAHORNG.csv
# 6201_亞弘電 YAHORNG.csv saving success.
# Saving 6215_和椿 Aurotek.csv
# 6215_和椿 Aurotek.csv saving success.
# Saving 8021_尖點 Topoint.csv
# 8021_尖點 Topoint.csv saving success.
# Saving 8201_無敵科技 BESTA.csv
# 8201_無敵科技 BESTA.csv saving success.
# Saving 2062_橋椿金屬 SSM.csv
# 2062_橋椿金屬 SSM.csv saving success.
# Saving 2514_龍邦國際 LONG BON.csv
# 2514_龍邦國際 LONG BON.csv saving success.
# Saving 2904_匯僑 POC.csv
# 2904_匯僑 POC.csv saving success.
# Saving 6184_大豐電 DAH FUNG CATV.csv
# 6184_大豐電 DAH FUNG CATV.csv saving success.
# Saving 8033_雷虎 TT.csv
# 8033_雷虎 TT.csv saving success.
# Saving 9902_台火開發 Tidehold.csv
# 9902_台火開發 Tidehold.csv saving success.
# Saving 9904_寶成工業 Pou Chen.csv
# 9904_寶成工業 Pou Chen.csv saving success.
# Saving 9905_大華金屬 GCM.csv
# 9905_大華金屬 GCM.csv saving success.
# Saving 9907_統一實業 Ton Yi.csv
# 9907_統一實業 Ton Yi.csv saving success.
# Saving 9910_豐泰企業 FT.csv
# 9910_豐泰企業 FT.csv saving success.
# Saving 9911_台灣櫻花 Taiwan Sakura.csv
# 9911_台灣櫻花 Taiwan Sakura.csv saving success.
# Saving 9914_美利達 MIC.csv
# 9914_美利達 MIC.csv saving success.
# Saving 9917_中保 Taiwan Secom.csv
# 9917_中保 Taiwan Secom.csv saving success.
# Saving 9919_康那香 KNH.csv
# 9919_康那香 KNH.csv saving success.
# Saving 9921_巨大機械 Giant Mfg..csv
# 9921_巨大機械 Giant Mfg..csv saving success.
# Saving 9924_臺灣福興 Taiwan Fu Hsing.csv
# 9924_臺灣福興 Taiwan Fu Hsing.csv saving success.
# Saving 9925_新保 SKS.csv
# 9925_新保 SKS.csv saving success.
# Saving 9927_泰銘 TMI.csv
# 9927_泰銘 TMI.csv saving success.
# Saving 9930_中聯資源 CHC.csv
# 9930_中聯資源 CHC.csv saving success.
# Saving 9933_中鼎 CTCI Corp..csv
# 9933_中鼎 CTCI Corp..csv saving success.
# Saving 9934_成霖 Globo.csv
# 9934_成霖 Globo.csv saving success.
# Saving 9935_慶豐富 Ching Feng.csv
# 9935_慶豐富 Ching Feng.csv saving success.
# Saving 9938_百和 Taiwan Paiho.csv
# 9938_百和 Taiwan Paiho.csv saving success.
# Saving 9939_宏全 Hon Chuan.csv
# 9939_宏全 Hon Chuan.csv saving success.
# Saving 9940_信義 Sinyi Realty.csv
# 9940_信義 Sinyi Realty.csv saving success.
# Saving 9942_茂順 MAO SHUN.csv
# 9942_茂順 MAO SHUN.csv saving success.
# Saving 9943_好樂迪 Holiday.csv
# 9943_好樂迪 Holiday.csv saving success.
# Saving 9944_新麗 Shinih.csv
# 9944_新麗 Shinih.csv saving success.
# Saving 9945_潤泰新 RUENTEX DEVELOP.csv
# 9945_潤泰新 RUENTEX DEVELOP.csv saving success.
# Saving 9955_佳龍 SDTI.csv
# 9955_佳龍 SDTI.csv saving success.

# %% [markdown]
# # 計算每支股票的月平均預期回報及波動率(標準差)

# %%
# To calculate the monthly average expected return and volatility (standard deviation) for each stock
import numpy as np
import pandas as pd

results = []

for each_stock_file in stock_file_names:
    df = pd.read_csv(each_stock_file)
    stock_code = df['股票代碼'].iloc[0] # Extract stock code
    stock_name = df['股票名稱'].iloc[0] # Extract stock name
    avg_return = df['預期回報'].mean() # Calculate the average expected monthly return
    
    # Calculate annualized expected return assuming compound interest
    annualized_return_compound = (1 + avg_return) ** 12 - 1
    
    # Calculate the standard deviation of expected returns as monthly volatility
    volatility = df['預期回報'].std()
    # Annualize the volatility by multiplying by the square root of 12
    annualized_volatility = volatility * np.sqrt(12)
    
    # Calculate the average trading volume for the stock
    avg_trading_vol = calculate_average_trading_volume(df)
    
    # Append the stock code, name, average trading volume, annualized return, and volatility to the results list
    results.append([stock_code, stock_name, avg_trading_vol, annualized_return_compound, annualized_volatility])

# Create a DataFrame from the results list with appropriate column names
results_df = pd.DataFrame(results, columns=['股票代碼', '股票名稱', '平均成交量', '平均預期回報', '波動率(標準差)'])
results_df.to_csv("MPT_algorithm_data.csv", index=False)
print("平均成交量、平均預期回報與標準差已儲存")
# Out:
# 平均成交量、平均預期回報與標準差已儲存

# %% [markdown]
# # 篩選掉十年來小於平均成交量的股票以確保流動性
# # 篩選掉預期回報小於零的股票以確保收益率

# %%
# To filter out stocks based on two criteria to ensure liquidity and a positive return rate over a decade.
import pandas as pd

file_path = r"C:\Users\Sydney\Desktop\KCL\Undergraduate\Year3\Final Individual Project\Data_Collection\Status_of_TWSE\per_stock_data\MPT_algorithm_data.csv"
df = pd.read_csv(file_path)

# Filter condition 1: Remove stocks with an average trading volume less than the given threshold
filter_condition1 = df['平均成交量'] > 57342.92360467928 #The average of all monthly average trading volumes 

# Filter condition 2: Remove stocks with an expected return less than zero
filter_condition2 = df['平均預期回報'] >= 0

# Combine the two conditions 
conbined_condition = filter_condition1 & filter_condition2

# Apply the combined condition to filter the DataFrame
filtered_df = df[conbined_condition]
# print(len(filtered_df))
# print(filtered_df['股票代碼'])

filtered_df.to_csv('Liquidity_Filtered_Stocks.csv', index=False)
print('Filtered stocks have been saved to Filtered_Stocks.csv.')
# Out:
# Filtered stocks have been saved to Filtered_Stocks.csv.
